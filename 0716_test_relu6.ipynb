# %% [markdown]
# # Import Stuff & Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchsummary import summary
import warnings
import os
import sys
from tqdm import tqdm
import cv2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
RESOLUTION = 64
block_frame = 8
frame_interval = 15

# %%
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %%
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5]),
    # transforms.Lambda(lambda x: x / 255.),
    transforms.Resize((RESOLUTION, RESOLUTION))
])

# %% [markdown]
# # Utils

# %%
def plot_image_from_list(__images, __labels, __count):
    plt.figure(figsize=(10, 10))
    for _i in range(__count[0] * __count[1]):
        plt.subplot(__count[0], __count[1], _i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        _img = __images[_i].to("cpu").numpy()
        plt.imshow(_img, cmap= "gray")
        plt.xlabel(__labels[_i])
    plt.show()

# %%
def plot_randomly_form_dataset(__dataset):
    images = []
    labels = []
    for _ in range(0, 25):
        index = torch.randint(0, len(__dataset), (1,)).item()
        image, label = __dataset[index]
        images.append(image[:,0].squeeze())
        labels.append(__dataset.label_id2str(label.item()))
    
    plot_image_from_list(images, labels, (5, 5))

# %%
def plot_sequence_form_dataset(__dataset, index):
    images = []
    labels = []
    for i in range(0, block_frame):
        image, label = __dataset[index]
        images.append(image[:,i].squeeze())
        labels.append(__dataset.label_id2str(label.item()))
    
    plot_image_from_list(images, labels, (1, block_frame))

# %%
def plot_randomly_form_dataset_model(__dataset, __model):
    images = []
    labels = []
    __model.to(device)
    for i in range(0, 25):
        index = torch.randint(0, len(__dataset), (1,)).item()
        image, label = __dataset[index]
        images.append(image[:,0].squeeze())
        result = model(image.unsqueeze(dim=0).to(device)).squeeze().cpu().argmax()
        
        labels.append(__dataset.label_id2str(label.item()) + " -> " + __dataset.label_id2str(result.item()))
 
    plot_image_from_list(images, labels, (5, 5))

# %% [markdown]
# # Dataset

# %%
DATA_SOURCE = {
   "Abuse": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Abuse",
    "Arrest": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Arrest",
    "Arson": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Arson",
    "Assault": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Assault",
    "Burglary": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Burglary",
    "Explosion": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Explosion",
    "Fighting": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Fighting",   
    "RoadAccidents":"D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\RoadAccidents",
    "Robbery": "D:\Anomaly-Detection-Dataset\Miniset_for_test_1\Robbery",
    "Shooting": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Shooting",
    "Shoplifting": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Shoplifting",
    "Stealing": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Stealing",
    "Vandalism": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Vandalism",
    "Normal": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Normal"
}
TEST_DATA_SOURCE = {
   "Abuse": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Abuse",
    "Arrest": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Arrest",
    "Arson": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Arson",
    "Assault": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Assault",
    "Burglary": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Burglary",
    "Explosion": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Explosion",
    "Fighting": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Fighting",   
    "RoadAccidents":"D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\RoadAccidents",
    "Robbery": "D:\Anomaly-Detection-Dataset\Miniset_for_test_1\Robbery",
    "Shooting": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Shooting",
    "Shoplifting": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Shoplifting",
    "Stealing": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Stealing",
    "Vandalism": "D:\\Anomaly-Detection-Dataset\\Miniset_for_test_1\\Vandalism",
    "Normal" : r"D:\Anomaly-Detection-Dataset\Normal_Videos_for_Event_Recognition\Normal_Videos_for_Event_Recognition"
}



# DATA_SOURCE = {
#     "Abuse": "E:\kaggle\input\crimeufcdataset\Anomaly_Dataset\Anomaly_Videos\Anomaly-Videos-Part-1\Abusetest",
#     "Arrest": "E:\kaggle\input\crimeufcdataset\Anomaly_Dataset\Anomaly_Videos\Anomaly-Videos-Part-1\Arresttest",
# }

# %%
import os

# 파일 경로를 설정합니다.
directory_path = r"D:\Anomaly-Detection-Dataset\Normal_Videos_for_Event_Recognition\Normal_Videos_for_Event_Recognition"

# 경로가 존재하는지 확인합니다.
if os.path.exists(directory_path):
    print("경로가 존재합니다.")
    # 디렉터리 내의 파일 목록을 출력합니다.
    print("디렉터리 내용:", os.listdir(directory_path))
else:
    print("지정된 경로를 찾을 수 없습니다.")
# Out:
# 경로가 존재합니다.
# 디렉터리 내용: ['Normal_Videos_015_x264.mp4', 'Normal_Videos_050_x264.mp4', 'Normal_Videos_100_x264.mp4', 'Normal_Videos_129_x264.mp4', 'Normal_Videos_150_x264.mp4', 'Normal_Videos_246_x264.mp4', 'Normal_Videos_247_x264.mp4', 'Normal_Videos_248_x264.mp4', 'Normal_Videos_251_x264.mp4', 'Normal_Videos_289_x264.mp4', 'Normal_Videos_310_x264.mp4', 'Normal_Videos_312_x264.mp4', 'Normal_Videos_317_x264.mp4', 'Normal_Videos_345_x264.mp4', 'Normal_Videos_352_x264.mp4', 'Normal_Videos_360_x264.mp4', 'Normal_Videos_365_x264.mp4', 'Normal_Videos_401_x264.mp4', 'Normal_Videos_417_x264.mp4', 'Normal_Videos_439_x264.mp4', 'Normal_Videos_452_x264.mp4', 'Normal_Videos_453_x264.mp4', 'Normal_Videos_478_x264.mp4', 'Normal_Videos_576_x264.mp4', 'Normal_Videos_597_x264.mp4', 'Normal_Videos_603_x264.mp4', 'Normal_Videos_606_x264.mp4', 'Normal_Videos_621_x264.mp4', 'Normal_Videos_634_x264.mp4', 'Normal_Videos_641_x264.mp4', 'Normal_Videos_656_x264.mp4', 'Normal_Videos_696_x264.mp4', 'Normal_Videos_704_x264.mp4', 'Normal_Videos_722_x264.mp4', 'Normal_Videos_745_x264.mp4', 'Normal_Videos_758_x264.mp4', 'Normal_Videos_781_x264.mp4', 'Normal_Videos_798_x264.mp4', 'Normal_Videos_801_x264.mp4', 'Normal_Videos_828_x264.mp4', 'Normal_Videos_831_x264.mp4', 'Normal_Videos_877_x264.mp4', 'Normal_Videos_881_x264.mp4', 'Normal_Videos_885_x264.mp4', 'Normal_Videos_892_x264.mp4', 'Normal_Videos_905_x264.mp4', 'Normal_Videos_912_x264.mp4', 'Normal_Videos_913_x264.mp4', 'Normal_Videos_914_x264.mp4', 'Normal_Videos_929_x264.mp4']

# %%
class CrimeDataset(Dataset):
    def __init__(self, __train=True, __train_test_split=0, __random_state=42):
        torch.manual_seed(__random_state)
        
        self._data = []
        self._labels = []
        self._inclusion_probability = __train_test_split if __train else 1.0 - __train_test_split
        self._frame_interval = frame_interval
        
        print(f"Loading {'train' if __train else 'test' } dataset...")
        for label, data_path in DATA_SOURCE.items():
            print(f"Loading Label {label}...")
            for file in tqdm(os.listdir(data_path)):
                if file.endswith(".mp4") and torch.rand(1).item() <= self._inclusion_probability:
                    path = os.path.join(data_path, file)
                    data, labels = self._parse_file(path, label)
                    # print(data)
                    # print(labels)
                    # print(data[0].shape)
                    # print(len(data))
                    # print(len(labels))
                    
                    
                    
                    self._data.extend(data)
                    self._labels.extend(labels)
        print(f"Finished loading {'train' if __train else 'test' } dataset... Loaded  {len(self._data)} images.")
    
    def _parse_file(self, __path, __label):
        if not os.path.exists(__path):
            return [], []
        
        data = []
        labels = []
        
        cap = cv2.VideoCapture(__path)
        
        frames = []
        success, image = cap.read()
        while success:
            try:
                if True:
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
                    Y, U, V = cv2.split(image)
                    image = transformer(Y)
                    frames.append(image)
                    
                    if len(frames) == block_frame:
                        stacked_frames = torch.stack(frames)
                        stacked_frames = stacked_frames.permute(1, 0, 2, 3)
                        data.append(stacked_frames)
                        labels.append(__label)
                        frames = frames[3:]
            except Exception as e:
                print(f"Error loading file {__path}: {e}")
            
            count = 0
            while success and count < self._frame_interval:
                success, image = cap.read()
                count += 1
                
        if len(frames) > 0 and len(frames) < block_frame:
            while len(frames) < block_frame:
                frames.append(frames[-1])
            stacked_frames = torch.stack(frames)
            stacked_frames = stacked_frames.permute(1, 0, 2, 3)
            data.append(stacked_frames)
            labels.append(__label)        
                
        return data, labels
        
    
    def label_str2id(self, __label):
        labels = DATA_SOURCE.keys()
        return list(labels).index(__label)

    def label_id2str(self, __label):
        labels = DATA_SOURCE.keys()
        return list(labels)[__label]
        
    def __len__(self):
        return len(self._labels)

    def __getitem__(self, __idx):
        data = self._data[__idx]
        label = self._labels[__idx]
        return data, torch.tensor([self.label_str2id(label)])

# %%
train_dataset = CrimeDataset(True)
test_dataset = CrimeDataset(False)
# Out:
# Loading train dataset...
# Loading Label Abuse...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Arrest...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Arson...
# 100%|██████████| 9/9 [00:00<?, ?it/s]
# Loading Label Assault...
# 100%|██████████| 10/10 [00:00<00:00, 10010.27it/s]
# Loading Label Burglary...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Explosion...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Fighting...
# 100%|██████████| 9/9 [00:00<?, ?it/s]
# Loading Label RoadAccidents...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Robbery...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Shooting...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Shoplifting...
# 100%|██████████| 9/9 [00:00<00:00, 8846.67it/s]
# Loading Label Stealing...
# 100%|██████████| 10/10 [00:00<00:00, 9981.68it/s]
# Loading Label Vandalism...
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Loading Label Normal...
# 100%|██████████| 12/12 [00:00<?, ?it/s]
# Finished loading train dataset... Loaded  0 images.
# Loading test dataset...
# Loading Label Abuse...
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Loading Label Arrest...
# 100%|██████████| 10/10 [00:05<00:00,  1.73it/s]
# Loading Label Arson...
# 100%|██████████| 9/9 [00:04<00:00,  1.82it/s]
# Loading Label Assault...
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# Loading Label Burglary...
# 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]
# Loading Label Explosion...
# 100%|██████████| 10/10 [00:05<00:00,  1.78it/s]
# Loading Label Fighting...
# 100%|██████████| 9/9 [00:08<00:00,  1.03it/s]
# Loading Label RoadAccidents...
# 100%|██████████| 10/10 [00:01<00:00,  5.47it/s]
# Loading Label Robbery...
# 100%|██████████| 10/10 [00:04<00:00,  2.47it/s]
# Loading Label Shooting...
# 100%|██████████| 10/10 [00:05<00:00,  1.69it/s]
# Loading Label Shoplifting...
# 100%|██████████| 9/9 [00:08<00:00,  1.07it/s]
# Loading Label Stealing...
# 100%|██████████| 10/10 [00:06<00:00,  1.62it/s]
# Loading Label Vandalism...
# 100%|██████████| 10/10 [00:05<00:00,  1.97it/s]
# Loading Label Normal...
# 100%|██████████| 12/12 [00:04<00:00,  2.51it/s]
# Finished loading test dataset... Loaded  10598 images.

# %%
print(test_dataset._data[0].shape)
plot_randomly_form_dataset(test_dataset)
# Out:
# torch.Size([1, 8, 64, 64])

# %%
# train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %% [markdown]
# # Model

# %%
class CrimeModelCNN(nn.Module):
    def __init__(self):
        super(CrimeModelCNN, self).__init__()
        self.conv1 = nn.Conv3d(1, 64, kernel_size=3, padding="same")
        self.ReLU = nn.ReLU6()
        self.max_pool1 = nn.MaxPool3d(2, 2)
        self.dropout1 = nn.Dropout(0.25)
        self.conv2 = nn.Conv3d(64, 128, kernel_size=3, padding="same")
        self.max_pool2 = nn.MaxPool3d(2, 2)
        self.dropout2 = nn.Dropout(0.25)
        self.conv3 = nn.Conv3d(128, 256, kernel_size=3, padding="same")
        self.max_pool3 = nn.MaxPool3d(2, 2)
        self.dropout3 = nn.Dropout(0.4)
        self.fc1 = nn.Linear(256 * block_frame * block_frame, 256)
        self.dropout4 = nn.Dropout(0.5)

    def forward(self, x):
        x = self.conv1(x)
        #print(x.shape)
        x = self.ReLU(x)
        #print(x.shape)
        x = self.max_pool1(x)
        #print(x.shape)
        x = self.dropout1(x)
        #print(x.shape)
        x = self.conv2(x)
        #print(x.shape)
        x = self.ReLU(x)
        #print(x.shape)
        x = self.max_pool2(x)
        #print(x.shape)
        x = self.dropout2(x)
        #print(x.shape)
        x = self.conv3(x)
        #print(x.shape)
        x = self.ReLU(x)
        #print(x.shape)
        x = self.max_pool3(x)
        #print(x.shape)
        x = self.dropout3(x)
        #print(x.shape)
        x = x.view(-1, 256 * block_frame * block_frame)
        #print(x.shape)
        x = self.fc1(x)
        #print(x.shape)
        #x = self.ReLU(x)
        #print(x.shape)
        #x = self.dropout4(x)
        #print(x.shape)
        return x

# %%
class CrimeModelLSTM(nn.Module):
    def __init__(self):
        super(CrimeModelLSTM, self).__init__()
        self.lstm1 = nn.LSTM(1, 8, batch_first=True, bidirectional=False)
        self.lstm2 = nn.LSTM(8, 8, batch_first=True, bidirectional=False)
        self.fc = nn.Linear(8, 4)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x = x[:, -1, :]
        x = self.fc(x)
        x = self.dropout(x)
        return x

# %%
# CNN과 LSTM을 동시에 사용하는 모델
class CrimeModel(nn.Module):
    def __init__(self):
        super(CrimeModel, self).__init__()
        self.cnn = CrimeModelCNN()
        self.lstm = CrimeModelLSTM()
        self.fc = nn.Linear(260, 14)  # Adjust the input size according to your concatenation axis


    def forward(self, x):
        x_cnn = x
        x_lstm = torch.reshape(x[:,:,0], (x.shape[0], RESOLUTION * RESOLUTION, 1))
        x_cnn = self.cnn(x_cnn)
        x_lstm = self.lstm(x_lstm)
        x_combined = torch.cat((x_cnn, x_lstm), dim=1)
        x = self.fc(x_combined)
#         return F.softmax(x, dim=1)
        return x

# %%
model = CrimeModel()
output = model(torch.rand(32, 1, 10, 64, 64))
print(output.shape)
# Out:
# torch.Size([32, 14])

# %% [markdown]
# # Training

# %%
model = nn.DataParallel(model)
model.to(device)
# Out:
# DataParallel(
#   (module): CrimeModel(
#     (cnn): CrimeModelCNN(
#       (conv1): Conv3d(1, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (ReLU): ReLU6()
#       (max_pool1): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (dropout1): Dropout(p=0.25, inplace=False)
#       (conv2): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (max_pool2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (dropout2): Dropout(p=0.25, inplace=False)
#       (conv3): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (max_pool3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (dropout3): Dropout(p=0.4, inplace=False)
#       (fc1): Linear(in_features=16384, out_features=256, bias=True)
#       (dropout4): Dropout(p=0.5, inplace=False)
#     )
#     (lstm): CrimeModelLSTM(
#       (lstm1): LSTM(1, 8, batch_first=True)
#       (lstm2): LSTM(8, 8, batch_first=True)
#       (fc): Linear(in_features=8, out_features=4, bias=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (fc): Linear(in_features=260, out_features=14, bias=True)
#   )
# )

# %%
model = torch.load("model.pt")

# %%
plot_randomly_form_dataset_model(test_dataset, model)

# %%
print(os.getcwd())
# Out:
# d:\urp_src

# %%
model = torch.load("model.pt")
model.to(device)
model.eval()  # Set the model to evaluation mode

def calculate_accuracy(model, data_loader, device):
    correct = 0
    total = 0

    with torch.no_grad():  # No need to compute gradients for evaluation
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to the device
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            for i in range(len(labels)):
                if (predicted[i] == labels[i]):
                    correct += 1
            
            print(labels.squeeze())
            print("predicted = {},\n total  = {}, correct = {}".format(predicted,total,correct))
            
            # print(outputs)

    accuracy = 100 * correct / total
    return accuracy

# Calculate accuracy on the test dataset
accuracy = calculate_accuracy(model, test_loader, device)
print(f'Accuracy of the model on the test dataset: {accuracy:.2f}%')
# Out:
# tensor([ 9,  6, 10,  4,  3,  3,  3,  6,  4, 10, 10,  7,  0,  2,  6,  2],
#        device='cuda:0')
# predicted = tensor([ 8,  1,  0,  3,  4,  8, 11,  6,  9,  2,  9,  8,  1,  0,  8,  9],
#        device='cuda:0'),
#  total  = 16, correct = 1
# tensor([ 9,  3,  3,  4,  3, 10,  8,  4,  9, 12,  6,  4,  8, 10, 10,  1],
#        device='cuda:0')
# predicted = tensor([ 1,  9,  9,  3,  5, 12,  0,  5,  2,  9,  8,  5, 10, 10, 12,  2],
#        device='cuda:0'),
#  total  = 32, correct = 2
# tensor([ 2,  8,  9,  0, 11, 10,  5,  4,  3,  6,  6,  2,  8, 13,  4,  6],
#        device='cuda:0')
# predicted = tensor([ 2,  8,  1,  0,  0, 10,  2,  5, 10,  2,  1,  4,  9, 13,  3,  1],
#        device='cuda:0'),
#  total  = 48, correct = 7
# tensor([ 6, 12,  1,  1, 12, 10,  8,  6,  3,  5, 11, 11,  6, 10,  3, 13],
#        device='cuda:0')
# predicted = tensor([ 1,  5,  2, 13, 11, 10, 10,  1,  9,  8,  0,  0,  0, 12,  3, 13],
#        device='cuda:0'),
#  total  = 64, correct = 10
# tensor([ 1,  4,  7,  9,  6, 10, 12,  4,  1,  1,  4,  8,  0,  4,  1, 12],
#        device='cuda:0')
# predicted = tensor([ 0,  9, 12,  2,  1,  9, 10,  3, 11,  3,  3,  8,  0,  3,  1,  8],
#        device='cuda:0'),
#  total  = 80, correct = 13
# tensor([ 6, 10,  1,  6,  5,  5,  2,  6, 10,  7, 11,  0,  4,  9,  4, 11],
#        device='cuda:0')
# predicted = tensor([1, 5, 9, 1, 2, 1, 6, 6, 0, 8, 8, 0, 3, 1, 9, 8], device='cuda:0'),
#  total  = 96, correct = 15
# tensor([ 3, 12,  3,  2,  8,  3,  0, 12,  5, 13,  4,  3,  6,  5, 12,  6],
#        device='cuda:0')
# predicted = tensor([ 4, 11,  4,  6,  9,  0, 11, 12, 10, 13,  5,  4,  8,  5,  5,  1],
#        device='cuda:0'),
#  total  = 112, correct = 18
# tensor([11, 10, 11,  8,  6, 13,  5,  4, 11,  8,  7,  2,  0,  2,  8,  6],
#        device='cuda:0')
# predicted = tensor([ 0,  9,  0,  8,  0, 13,  6,  3, 11,  6,  5, 12, 11, 13,  8,  6],
#        device='cuda:0'),
#  total  = 128, correct = 23
# tensor([11,  3,  9,  1,  3, 13,  6,  4,  5,  9,  3,  3,  1,  1,  9,  4],
#        device='cuda:0')
# predicted = tensor([ 7,  9,  1,  1,  5, 13,  8,  3, 13,  9,  9, 10,  8, 13,  2,  5],
#        device='cuda:0'),
#  total  = 144, correct = 26
# tensor([11,  3,  3, 10,  3, 10,  3,  0,  3, 11,  2,  1, 10,  4,  0, 13],
#        device='cuda:0')
# predicted = tensor([ 0,  4,  9,  9,  4,  9,  9,  5,  9, 10,  4, 13,  4,  9, 11, 13],
#        device='cuda:0'),
#  total  = 160, correct = 27
# tensor([10,  2,  6, 13, 11,  3, 12, 10,  5,  1,  5, 12,  6, 12,  3,  9],
#        device='cuda:0')
# predicted = tensor([10,  4,  1, 13,  8,  8,  3, 10,  2,  2, 13,  6,  5,  5,  1,  1],
#        device='cuda:0'),
#  total  = 176, correct = 30
# tensor([11,  6,  4,  0, 10,  6,  2,  5,  2,  9,  5,  5,  2,  4, 12, 12],
#        device='cuda:0')
# predicted = tensor([11,  8,  5,  1, 10,  6,  3,  5,  9,  2,  5, 10,  6, 10,  4, 11],
#        device='cuda:0'),
#  total  = 192, correct = 35
# tensor([ 3,  6,  8,  3,  3,  2,  2,  4,  1,  5,  8,  3,  3,  4, 10,  4],
#        device='cuda:0')
# predicted = tensor([10, 10,  8,  4,  4,  2,  0,  1,  3, 10,  5,  9,  4, 12,  2,  3],
#        device='cuda:0'),
#  total  = 208, correct = 37
# tensor([ 2, 10,  6,  6,  8, 12,  2, 10,  6,  4,  1,  1, 10, 10,  3, 12],
#        device='cuda:0')
# predicted = tensor([ 0,  0,  6,  0,  9, 11,  2, 10,  8,  5,  1,  9,  4, 10, 10,  6],
#        device='cuda:0'),
#  total  = 224, correct = 42
# tensor([ 3, 10,  8, 12,  0, 10,  2,  0,  9,  9, 10,  4,  4, 12, 10, 10],
#        device='cuda:0')
# predicted = tensor([ 5,  2, 10, 10,  5,  2,  6,  1,  1,  9,  9,  3,  3, 11, 10,  2],
#        device='cuda:0'),
#  total  = 240, correct = 44
# tensor([10,  0,  9, 10,  4,  3,  7,  0,  4,  6,  2,  2,  6, 11,  8,  1],
#        device='cuda:0')
# predicted = tensor([12,  1,  2, 10,  5,  9,  5, 11,  6, 10, 12,  3,  8,  2, 10,  8],
#        device='cuda:0'),
#  total  = 256, correct = 45
# tensor([ 8,  3, 11,  5, 11,  3,  9,  6, 10,  1,  8, 11,  6, 10,  5,  6],
#        device='cuda:0')
# predicted = tensor([ 8,  4, 11,  9,  8,  8, 13,  3, 12, 13, 10,  0,  6,  2, 10,  1],
#        device='cuda:0'),
#  total  = 272, correct = 48
# tensor([ 0, 10, 10, 10,  3,  1,  3, 11, 13,  2,  7,  4,  6,  1,  0,  2],
#        device='cuda:0')
# predicted = tensor([ 0, 13,  5,  2,  4, 13,  8,  0, 13, 12, 11,  5,  1,  8,  1,  2],
#        device='cuda:0'),
#  total  = 288, correct = 51
# tensor([10,  2,  5,  8, 11,  5, 13, 13, 10,  0,  3, 10,  0,  1,  3,  8],
#        device='cuda:0')
# predicted = tensor([ 2,  6, 13,  9, 11,  2, 13, 13,  4, 11,  5,  2,  1, 13,  4,  9],
#        device='cuda:0'),
#  total  = 304, correct = 54
# tensor([ 1,  5,  6,  9, 10,  2,  0,  1,  0, 11, 12,  6, 12,  4,  9,  9],
#        device='cuda:0')
# predicted = tensor([ 4,  2,  8,  1,  2, 11,  3,  8,  6, 11,  6, 10,  8,  9,  1,  2],
#        device='cuda:0'),
#  total  = 320, correct = 55
# tensor([ 3, 10, 12, 10,  5,  2,  1,  4,  0,  3,  3,  6, 12,  0,  6, 13],
#        device='cuda:0')
# predicted = tensor([ 8,  0,  8,  6,  0, 12,  0, 10, 11,  8,  4,  1,  5,  0,  3, 13],
#        device='cuda:0'),
#  total  = 336, correct = 57
# tensor([ 5, 12,  8, 11, 10, 13,  2,  2, 11,  6,  9,  5,  4, 12, 10,  6],
#        device='cuda:0')
# predicted = tensor([ 5,  5,  1,  8,  5, 13,  9,  1,  0,  8,  1, 11,  9,  5,  8, 10],
#        device='cuda:0'),
#  total  = 352, correct = 59
# tensor([ 4,  4,  6, 10,  5, 10,  0,  4,  9,  3,  4,  2,  4,  3,  1, 10],
#        device='cuda:0')
# predicted = tensor([ 5,  5,  1, 10,  5, 10, 11,  3,  1,  9,  5, 12,  5,  4,  9,  2],
#        device='cuda:0'),
#  total  = 368, correct = 62
# tensor([ 3, 12,  1,  3,  8,  9,  9,  3,  9, 12,  7, 12,  3, 13,  9,  3],
#        device='cuda:0')
# predicted = tensor([ 8, 11,  1,  9,  9,  2,  2,  5,  9,  4,  5,  3, 10, 13,  2,  9],
#        device='cuda:0'),
#  total  = 384, correct = 65
# tensor([ 5,  1, 12, 11,  2, 10,  4, 11,  8, 12,  8, 12,  5,  3,  4, 13],
#        device='cuda:0')
# predicted = tensor([10,  0, 12,  8, 13, 10,  3, 11,  3,  0,  8,  6, 10,  9,  5, 13],
#        device='cuda:0'),
#  total  = 400, correct = 70
# tensor([ 6,  2,  9,  3, 10, 10,  2,  3,  0,  8,  2, 10, 13,  1,  3,  0],
#        device='cuda:0')
# predicted = tensor([ 1, 12, 13,  5,  0, 12, 12,  9,  3, 10,  6,  4, 12,  0,  5,  5],
#        device='cuda:0'),
#  total  = 416, correct = 70
# tensor([ 4,  4,  0, 10, 13, 12, 11, 11,  3, 11,  2, 10,  5,  4, 13, 11],
#        device='cuda:0')
# predicted = tensor([ 2,  9,  6, 13, 13,  6,  0,  8,  8,  8,  2,  2,  1,  9, 12,  0],
#        device='cuda:0'),
#  total  = 432, correct = 72
# tensor([ 5,  6,  9,  3, 11,  1,  0, 10, 12, 12,  6,  2,  3,  6,  4, 10],
#        device='cuda:0')
# predicted = tensor([10,  6,  2,  5, 11,  0,  5, 10,  1,  9,  5, 13, 10,  5,  9, 12],
#        device='cuda:0'),
#  total  = 448, correct = 75
# tensor([ 2,  8, 13, 10,  5,  2,  4,  9, 12,  4, 12,  6, 10, 10,  1,  6],
#        device='cuda:0')
# predicted = tensor([13, 11, 13, 10,  5,  3,  5,  9,  9,  3,  6,  2,  0,  0,  1,  8],
#        device='cuda:0'),
#  total  = 464, correct = 80
# tensor([10, 10, 11,  7,  6,  6,  4,  9,  9,  0,  0,  6,  3, 10,  0,  7],
#        device='cuda:0')
# predicted = tensor([13,  0,  8,  8,  1,  8,  3,  2,  1,  5,  3,  6,  4, 10, 11, 10],
#        device='cuda:0'),
#  total  = 480, correct = 82
# tensor([11, 11,  3, 13, 12,  6,  9,  9, 10, 13, 11, 13,  1,  6,  0,  1],
#        device='cuda:0')
# predicted = tensor([10, 10,  9, 13,  5,  9,  1,  5,  2, 13,  8, 13,  0,  0,  0,  0],
#        device='cuda:0'),
#  total  = 496, correct = 86
# tensor([ 4,  9,  1,  2, 13, 12, 13, 12,  0, 10, 11, 12,  4,  4,  9, 11],
#        device='cuda:0')
# predicted = tensor([ 3,  9,  4,  6, 13,  8,  0,  2, 11, 13,  7, 12,  3,  9,  1,  0],
#        device='cuda:0'),
#  total  = 512, correct = 89
# tensor([ 4,  8,  0,  1, 12,  9,  4,  7,  8, 10,  3,  0, 13,  4, 11,  5],
#        device='cuda:0')
# predicted = tensor([13,  9,  5,  8, 11,  6,  5,  8,  8,  9,  5,  5, 12,  9,  8, 13],
#        device='cuda:0'),
#  total  = 528, correct = 90
# tensor([ 3,  3, 12, 12,  3,  4,  6,  6,  6,  6,  4,  2,  5,  2,  2,  0],
#        device='cuda:0')
# predicted = tensor([ 5,  1,  8,  6,  9,  9,  8,  6,  6,  8,  5,  1, 13,  3,  2,  5],
#        device='cuda:0'),
#  total  = 544, correct = 93
# tensor([ 4,  8,  5, 10,  4, 11,  2,  0, 10,  5,  5,  6,  5,  4, 11,  5],
#        device='cuda:0')
# predicted = tensor([ 5,  6,  5,  4,  9,  0,  1, 11,  8, 12,  5,  8, 12,  5,  0,  2],
#        device='cuda:0'),
#  total  = 560, correct = 95
# tensor([11,  0, 10, 13,  8,  1, 11,  4, 10,  4,  3,  5, 12,  4,  0, 10],
#        device='cuda:0')
# predicted = tensor([11, 11,  0,  5, 10,  1, 11,  5, 10,  3,  9, 10,  4,  3, 11,  8],
#        device='cuda:0'),
#  total  = 576, correct = 99
# tensor([ 3,  0, 10,  3, 11,  7, 11,  2,  4,  5,  3,  4,  4, 10,  3,  1],
#        device='cuda:0')
# predicted = tensor([ 9, 11, 12,  9, 11,  8,  8, 12, 10, 10,  4,  9, 10, 12,  6,  0],
#        device='cuda:0'),
#  total  = 592, correct = 100
# tensor([ 2, 11,  4, 10, 13,  6, 11,  5,  0,  8,  5,  3,  1,  6, 11,  1],
#        device='cuda:0')
# predicted = tensor([ 2,  8,  5, 10,  0,  6,  8, 12, 11,  8,  5, 13,  0,  5,  8, 13],
#        device='cuda:0'),
#  total  = 608, correct = 105
# tensor([ 8,  2,  2,  6,  3, 11,  6, 10,  3,  0,  3, 12, 11,  2, 13,  1],
#        device='cuda:0')
# predicted = tensor([ 8, 12, 12,  2,  4,  2,  1,  8,  0,  3,  9,  5, 11,  9, 13,  3],
#        device='cuda:0'),
#  total  = 624, correct = 108
# tensor([12,  9, 12,  4, 13,  1,  0,  6,  4,  2,  4, 12,  6, 10,  4, 11],
#        device='cuda:0')
# predicted = tensor([ 6,  2,  6,  3, 13, 13, 11,  6,  3,  2,  5,  2,  8, 10,  6,  0],
#        device='cuda:0'),
#  total  = 640, correct = 112
# tensor([ 3,  4, 13,  9,  3, 11,  1,  9,  9,  9,  0,  0,  3, 11,  3,  1],
#        device='cuda:0')
# predicted = tensor([ 5,  9, 13,  9,  5, 10,  4,  6,  1,  1,  9,  3,  9, 11,  9, 12],
#        device='cuda:0'),
#  total  = 656, correct = 115
# tensor([10, 11, 13,  9,  5,  3,  5,  2,  1,  9,  4,  6,  5,  6,  0,  7],
#        device='cuda:0')
# predicted = tensor([12,  8, 13,  9, 13,  8,  2,  5,  9,  6, 10,  6,  5,  8, 11,  8],
#        device='cuda:0'),
#  total  = 672, correct = 119
# tensor([11,  8,  9,  7,  4, 10, 10, 12,  4, 12,  5,  4,  6,  8,  3,  0],
#        device='cuda:0')
# predicted = tensor([ 8,  6,  2, 10,  9, 10,  2,  8,  5, 10,  3,  1,  8,  9,  9, 11],
#        device='cuda:0'),
#  total  = 688, correct = 120
# tensor([11,  4,  6, 12,  8,  5,  5,  4,  0,  6, 10, 10,  2,  6,  1,  9],
#        device='cuda:0')
# predicted = tensor([11, 10,  1, 11,  9, 13, 10,  5, 13,  3,  0, 10,  6, 11,  7,  0],
#        device='cuda:0'),
#  total  = 704, correct = 122
# tensor([ 5, 12, 13, 11,  1,  8, 13,  2,  3, 10,  3,  8,  0,  2,  5,  0],
#        device='cuda:0')
# predicted = tensor([ 5,  6,  5, 11,  4,  8, 13,  9, 10,  2,  1, 10,  1,  5, 13, 13],
#        device='cuda:0'),
#  total  = 720, correct = 126
# tensor([ 9, 10, 12,  0, 12, 12,  0,  0,  6,  5,  4, 13,  4, 12, 11, 11],
#        device='cuda:0')
# predicted = tensor([11,  9,  9,  1, 11, 12, 11,  3,  5, 10,  5,  5,  3, 11,  0,  8],
#        device='cuda:0'),
#  total  = 736, correct = 127
# tensor([ 0,  4,  0,  9, 12, 10,  4, 11, 10,  4,  0,  9,  6, 12,  8, 11],
#        device='cuda:0')
# predicted = tensor([ 3,  9, 11,  9,  5,  8,  3,  0,  5,  5,  1,  9,  8,  6,  8,  0],
#        device='cuda:0'),
#  total  = 752, correct = 130
# tensor([ 0,  6, 13, 11,  5, 10,  9, 10, 12, 10,  3, 11, 12, 11, 12, 12],
#        device='cuda:0')
# predicted = tensor([11,  6, 13,  0,  0, 12,  1,  6,  6,  0,  9,  0,  8, 11,  6,  5],
#        device='cuda:0'),
#  total  = 768, correct = 133
# tensor([ 9, 10, 13, 13,  1,  4, 12,  1,  3,  2, 11, 13,  1, 11, 12,  3],
#        device='cuda:0')
# predicted = tensor([ 1,  2, 13, 13,  3,  3, 10, 13,  5,  2,  8, 13,  0,  8,  6,  4],
#        device='cuda:0'),
#  total  = 784, correct = 137
# tensor([ 1, 12,  9,  6, 10,  9,  8,  3, 10, 12,  3,  5,  8,  3, 13,  2],
#        device='cuda:0')
# predicted = tensor([ 9,  3,  1,  1,  4,  6,  5,  5,  8, 11,  5,  6,  8,  9, 13,  2],
#        device='cuda:0'),
#  total  = 800, correct = 140
# tensor([ 0,  6,  9, 11, 11,  3,  6,  4,  2, 10, 11,  6,  4, 10,  4,  6],
#        device='cuda:0')
# predicted = tensor([ 3,  1,  2, 11,  0,  5,  8,  9,  9,  9, 11,  1,  3, 10,  3,  1],
#        device='cuda:0'),
#  total  = 816, correct = 143
# tensor([ 5,  9,  4, 12,  9,  4,  0, 13, 12,  9,  6,  8,  6,  8,  8,  9],
#        device='cuda:0')
# predicted = tensor([10,  1,  9,  2,  2,  5,  0, 13,  3,  1,  2,  8,  6, 10,  8,  9],
#        device='cuda:0'),
#  total  = 832, correct = 149
# tensor([ 3,  3,  6, 11,  8,  3,  4,  5,  7,  2,  6,  0,  8, 10, 12,  0],
#        device='cuda:0')
# predicted = tensor([ 4,  5,  1,  8,  8,  8,  9,  3,  3,  2,  8,  0,  8, 10, 11, 11],
#        device='cuda:0'),
#  total  = 848, correct = 154
# tensor([ 5,  6, 12,  9,  7, 12,  6,  5,  1,  0, 10,  2,  6,  3, 12,  3],
#        device='cuda:0')
# predicted = tensor([ 5,  1, 12,  8,  4, 11,  8, 13,  9, 13,  8,  2,  1,  5,  8,  0],
#        device='cuda:0'),
#  total  = 864, correct = 157
# tensor([12, 10,  3, 11,  3,  2, 12, 10, 11,  3, 10,  9,  5,  3, 12,  8],
#        device='cuda:0')
# predicted = tensor([11,  5,  5, 10,  9,  0,  9, 10, 11,  4, 10,  1, 10,  9,  5,  4],
#        device='cuda:0'),
#  total  = 880, correct = 160
# tensor([ 4,  0,  9, 11,  9,  8,  2, 13,  4, 12,  4,  9,  3,  1, 11,  1],
#        device='cuda:0')
# predicted = tensor([10,  0,  0,  8,  1,  9,  8, 13,  5, 11,  4,  2,  9,  9,  8,  9],
#        device='cuda:0'),
#  total  = 896, correct = 163
# tensor([ 2,  6,  5,  3,  6, 13,  5,  0,  4,  4, 10,  1,  6, 10,  4,  0],
#        device='cuda:0')
# predicted = tensor([ 9,  6,  2, 10,  2,  5,  2,  3,  3,  6,  9,  2,  6,  0,  5, 11],
#        device='cuda:0'),
#  total  = 912, correct = 165
# tensor([ 9,  6,  5,  3,  8,  0,  2,  3,  3,  0,  4, 10,  3,  3, 13, 10],
#        device='cuda:0')
# predicted = tensor([ 1,  1, 13,  8,  6,  3,  2,  5,  6, 11,  3, 12,  8,  9, 13,  9],
#        device='cuda:0'),
#  total  = 928, correct = 167
# tensor([ 1,  3,  3,  0, 11,  4,  1, 12,  3, 11,  0, 10,  3,  3,  8,  3],
#        device='cuda:0')
# predicted = tensor([ 0,  3,  4,  5, 11, 10,  9, 11,  5,  0,  3, 12,  7,  9,  6,  9],
#        device='cuda:0'),
#  total  = 944, correct = 169
# tensor([10,  0,  3,  3,  1, 10,  0,  8, 10, 12, 11, 10, 12,  4, 12,  2],
#        device='cuda:0')
# predicted = tensor([ 8, 11,  9, 10,  0,  2,  1,  9,  2,  5,  8, 12,  6,  9,  9,  3],
#        device='cuda:0'),
#  total  = 960, correct = 169
# tensor([ 9,  3,  9,  0, 11, 13, 11,  1,  6, 12,  2,  8,  1, 10,  5, 11],
#        device='cuda:0')
# predicted = tensor([ 9,  5,  1, 11,  8, 13,  8,  4,  8, 10,  0, 10,  0,  8,  7,  2],
#        device='cuda:0'),
#  total  = 976, correct = 171
# tensor([ 1,  4, 11,  6,  5,  5,  2,  1,  6,  3,  2,  0,  3,  3,  9,  4],
#        device='cuda:0')
# predicted = tensor([ 2,  3,  8,  1,  6,  2, 12,  9,  3,  4, 12,  1,  4,  8,  0, 13],
#        device='cuda:0'),
#  total  = 992, correct = 171
# tensor([10,  3,  6,  8, 12, 13,  1, 10,  6, 13,  9,  4,  0, 10,  7,  4],
#        device='cuda:0')
# predicted = tensor([ 0,  6,  8,  9, 11, 12, 13, 10, 10, 13, 13,  3,  1, 13,  8,  5],
#        device='cuda:0'),
#  total  = 1008, correct = 173
# tensor([ 0, 13,  4,  3,  6,  9,  6,  0,  9, 11,  8,  9,  4,  4, 13,  0],
#        device='cuda:0')
# predicted = tensor([ 0, 13, 13,  9,  1,  1,  8,  0,  1,  0, 10,  2,  3, 10, 12,  5],
#        device='cuda:0'),
#  total  = 1024, correct = 176
# tensor([10,  3,  3,  6,  3,  0,  4,  8,  5,  3,  5,  8, 11,  2,  8, 10],
#        device='cuda:0')
# predicted = tensor([10,  4, 10,  1,  6,  3, 10,  9, 10,  8, 10,  9,  8,  2, 10, 10],
#        device='cuda:0'),
#  total  = 1040, correct = 179
# tensor([ 9, 11,  2,  6,  2,  4, 12,  1, 11,  3, 10, 10, 10,  8,  6,  7],
#        device='cuda:0')
# predicted = tensor([ 2, 10, 13,  1, 12,  5, 13, 13,  8,  5,  7,  8,  2,  9,  5,  8],
#        device='cuda:0'),
#  total  = 1056, correct = 179
# tensor([ 1, 10, 10,  3,  4,  3,  8, 12, 12,  4,  0,  0,  2,  1, 10,  9],
#        device='cuda:0')
# predicted = tensor([ 4,  9,  0,  4,  3,  8,  8,  9, 12,  5,  3,  1,  0,  9, 12,  1],
#        device='cuda:0'),
#  total  = 1072, correct = 181
# tensor([ 6,  0, 10,  1,  9,  5, 12,  0,  4,  3,  2,  1,  5,  3,  6, 11],
#        device='cuda:0')
# predicted = tensor([ 1,  3,  8, 13,  2, 13,  5, 10, 12,  9,  2,  0,  1,  5,  8,  8],
#        device='cuda:0'),
#  total  = 1088, correct = 182
# tensor([ 8, 10, 11,  5,  5, 13,  2, 10,  3,  0, 13,  9,  8,  3,  4, 12],
#        device='cuda:0')
# predicted = tensor([10, 10,  8, 11, 13,  5,  2,  7,  9,  0,  5,  2,  9,  5,  3, 12],
#        device='cuda:0'),
#  total  = 1104, correct = 186
# tensor([11, 12, 11,  9, 11,  4,  6,  0,  4,  1,  1, 10,  3, 10,  4, 11],
#        device='cuda:0')
# predicted = tensor([ 0, 11,  0,  9, 11,  3,  6, 11, 10,  4,  0, 12,  9,  5,  3, 11],
#        device='cuda:0'),
#  total  = 1120, correct = 190
# tensor([ 1,  4,  3,  8, 11,  7,  4,  3,  2,  3, 11,  3,  6,  3,  9, 13],
#        device='cuda:0')
# predicted = tensor([ 3, 10, 10,  8, 11,  8,  3, 10, 12, 10, 11,  5,  8, 10,  1, 13],
#        device='cuda:0'),
#  total  = 1136, correct = 194
# tensor([ 6,  4,  4,  5, 12, 10, 12,  6, 12,  8,  7,  1,  3,  1, 10, 11],
#        device='cuda:0')
# predicted = tensor([ 1,  3,  5,  9,  6, 12,  0,  6,  8,  8,  3, 12, 10,  8,  0,  7],
#        device='cuda:0'),
#  total  = 1152, correct = 196
# tensor([12,  0,  5,  9, 13,  1,  0,  9,  6,  0,  4,  8, 13,  0, 11, 12],
#        device='cuda:0')
# predicted = tensor([ 6, 11,  1,  6, 13,  0,  3,  2,  7,  0,  5,  8, 13,  3,  0,  3],
#        device='cuda:0'),
#  total  = 1168, correct = 200
# tensor([ 2, 11, 10,  2,  5,  5,  3, 13,  9,  3,  5,  4, 10, 10,  4,  5],
#        device='cuda:0')
# predicted = tensor([ 2,  6,  0,  0, 10,  5,  8, 13,  9,  8,  6, 10,  9,  2,  9, 10],
#        device='cuda:0'),
#  total  = 1184, correct = 204
# tensor([12,  0,  8,  4,  1,  5,  3, 12,  5,  3,  3, 11,  5, 13,  6,  3],
#        device='cuda:0')
# predicted = tensor([ 6, 11,  8,  5, 12,  2,  1, 11, 13,  4,  3,  0,  1, 13,  1, 10],
#        device='cuda:0'),
#  total  = 1200, correct = 207
# tensor([ 4,  3,  2, 11,  3, 11, 10, 10, 11,  1,  4,  1,  4, 10,  1,  4],
#        device='cuda:0')
# predicted = tensor([13, 10,  9,  0,  1,  7, 12,  2,  0,  3,  3,  0,  3, 10,  3,  5],
#        device='cuda:0'),
#  total  = 1216, correct = 208
# tensor([ 5, 13,  7,  4,  2, 10,  4, 13,  5, 11,  1, 12,  9,  8, 13,  0],
#        device='cuda:0')
# predicted = tensor([ 6, 13,  4,  3,  3, 10,  5, 13, 10,  0,  9, 12,  2,  8, 13, 11],
#        device='cuda:0'),
#  total  = 1232, correct = 214
# tensor([12,  4, 10,  8,  3,  5, 12, 10, 10,  6,  5,  6,  3,  3,  9, 12],
#        device='cuda:0')
# predicted = tensor([ 9,  3,  4,  9,  5,  5,  8,  2,  4,  1,  6,  6, 10,  9,  2,  8],
#        device='cuda:0'),
#  total  = 1248, correct = 216
# tensor([ 8,  6, 12,  1,  0,  1,  5,  3,  1, 13, 11,  5,  8,  5,  5, 13],
#        device='cuda:0')
# predicted = tensor([12,  8,  0,  1,  1,  8,  5,  9,  1, 13,  8,  2, 13,  5,  5, 13],
#        device='cuda:0'),
#  total  = 1264, correct = 223
# tensor([ 5,  5,  4,  5,  4,  9,  8,  6,  9,  4,  9,  4,  6, 13,  6,  3],
#        device='cuda:0')
# predicted = tensor([11, 12,  3, 10,  9,  2, 13,  1,  2,  6,  8,  5,  8, 13,  6,  9],
#        device='cuda:0'),
#  total  = 1280, correct = 225
# tensor([ 7,  4,  1,  3, 13,  3, 10, 12,  5,  7,  4,  3, 11,  5,  3,  6],
#        device='cuda:0')
# predicted = tensor([ 9,  9,  0,  4, 13,  4,  9,  3,  2,  7,  3, 10, 10,  2,  4,  3],
#        device='cuda:0'),
#  total  = 1296, correct = 227
# tensor([ 0, 10, 13,  1, 10,  0,  4, 10,  6,  6,  9,  0, 10, 11,  6,  5],
#        device='cuda:0')
# predicted = tensor([ 0,  2, 13,  0,  2,  3,  5,  5,  1,  8,  1,  5, 10,  8,  6,  2],
#        device='cuda:0'),
#  total  = 1312, correct = 231
# tensor([12,  3,  3,  3,  3,  2,  8,  3, 11, 10,  5,  6, 12,  8,  0, 12],
#        device='cuda:0')
# predicted = tensor([11, 13,  8,  9, 10,  9,  9,  9,  8,  0, 13,  1,  8,  8,  8,  8],
#        device='cuda:0'),
#  total  = 1328, correct = 232
# tensor([ 4, 11, 10, 11, 10,  1,  6, 11,  0,  5,  1, 10, 10, 13, 12, 12],
#        device='cuda:0')
# predicted = tensor([ 3, 11, 10,  8,  0, 13,  8,  2,  0,  5,  6, 13, 13, 13,  9,  6],
#        device='cuda:0'),
#  total  = 1344, correct = 237
# tensor([10, 10,  4,  0,  9,  1,  3, 13,  6,  4, 13,  9,  0,  0,  8,  9],
#        device='cuda:0')
# predicted = tensor([13,  9,  9,  1,  6,  1,  9, 13,  8, 10, 13,  9,  3, 11,  8,  1],
#        device='cuda:0'),
#  total  = 1360, correct = 242
# tensor([ 6,  1, 11,  6, 10,  4, 10,  6, 10,  4, 11,  9, 10,  6,  8,  4],
#        device='cuda:0')
# predicted = tensor([ 1,  0,  8,  3, 10,  5,  9,  6, 13, 10,  0,  0,  0,  6,  5,  3],
#        device='cuda:0'),
#  total  = 1376, correct = 245
# tensor([ 3, 12,  9,  0,  9,  6,  5, 12,  4,  5,  4,  9, 10,  3,  6,  2],
#        device='cuda:0')
# predicted = tensor([ 0,  8,  1,  5, 13,  1,  2, 11,  9,  3,  5,  7, 12,  9,  1,  5],
#        device='cuda:0'),
#  total  = 1392, correct = 245
# tensor([ 0,  9,  4,  0,  2,  8,  6, 12, 11,  1,  2, 11, 10,  3,  7, 11],
#        device='cuda:0')
# predicted = tensor([11,  9,  5,  5,  3, 10,  5, 11,  0,  4,  6, 11,  8,  4,  4,  0],
#        device='cuda:0'),
#  total  = 1408, correct = 247
# tensor([ 4,  6,  5, 13,  6, 10, 12,  6, 10,  5,  6,  9, 10, 11,  3,  0],
#        device='cuda:0')
# predicted = tensor([ 5,  1,  1, 13,  6,  0,  6,  0,  2,  1,  8,  1,  2, 11, 10, 11],
#        device='cuda:0'),
#  total  = 1424, correct = 250
# tensor([ 4,  8,  4, 11, 12, 10,  0, 12,  7,  9, 12, 11, 10,  3,  3,  4],
#        device='cuda:0')
# predicted = tensor([ 3,  8,  3, 11,  8, 10,  3,  2, 10,  2, 11, 10,  2,  4,  0, 13],
#        device='cuda:0'),
#  total  = 1440, correct = 253
# tensor([ 6,  3,  9,  4,  3,  0, 10,  3,  3, 10, 10,  4, 10, 11, 11,  3],
#        device='cuda:0')
# predicted = tensor([ 1,  4,  1, 10,  9,  0, 10,  5,  4, 13,  9,  3,  2,  0, 11,  5],
#        device='cuda:0'),
#  total  = 1456, correct = 256
# tensor([11,  4, 12,  9,  1,  6,  7, 12,  1,  7, 10,  3,  9,  3,  9,  8],
#        device='cuda:0')
# predicted = tensor([ 2,  9, 11, 13, 13,  2,  8,  8,  3,  8,  8,  5,  2,  8,  2,  8],
#        device='cuda:0'),
#  total  = 1472, correct = 257
# tensor([ 6,  3,  0,  6, 11,  1,  6,  6,  6,  6, 12,  3,  4, 12, 10,  4],
#        device='cuda:0')
# predicted = tensor([ 1,  9,  5, 10,  0,  9,  1,  1,  1, 12, 10,  1, 13,  5, 12,  3],
#        device='cuda:0'),
#  total  = 1488, correct = 257
# tensor([ 6,  5, 13,  5,  4, 12,  9,  2,  4, 12, 10,  9,  3,  6,  1, 11],
#        device='cuda:0')
# predicted = tensor([10, 10, 13,  2,  5,  5,  9,  9,  3,  5,  2,  9,  1,  1,  9, 11],
#        device='cuda:0'),
#  total  = 1504, correct = 261
# tensor([ 0,  3, 11,  5, 11,  5,  4,  0, 13,  4,  8, 12, 11,  5,  6,  4],
#        device='cuda:0')
# predicted = tensor([ 1,  9, 10,  6,  8,  2,  6, 11, 13,  3, 10, 11, 11,  6,  1,  5],
#        device='cuda:0'),
#  total  = 1520, correct = 263
# tensor([ 7,  6,  5, 10,  3,  6, 11, 11, 10,  5,  9,  0, 10,  1, 11,  5],
#        device='cuda:0')
# predicted = tensor([ 4,  2,  6, 12,  5,  8, 11, 11, 12, 10,  1,  0,  2,  0, 11,  5],
#        device='cuda:0'),
#  total  = 1536, correct = 268
# tensor([ 1,  0,  9, 13,  2, 10,  1, 10,  7,  5, 13,  0,  4,  6, 10,  5],
#        device='cuda:0')
# predicted = tensor([ 4,  3,  1, 13,  6,  0,  4,  2,  8, 10,  5,  5,  3,  1, 10, 10],
#        device='cuda:0'),
#  total  = 1552, correct = 270
# tensor([6, 2, 5, 4, 2, 6, 6, 3, 3, 3, 5, 0, 6, 2, 9, 4], device='cuda:0')
# predicted = tensor([ 1,  2, 13,  5, 13, 10,  1,  9,  5,  1, 10, 13,  8,  6,  6, 12],
#        device='cuda:0'),
#  total  = 1568, correct = 271
# tensor([10,  6, 13,  7,  7,  4, 11,  9, 12,  5, 13,  8,  8, 11,  2, 13],
#        device='cuda:0')
# predicted = tensor([ 0,  6, 13, 12,  5,  5,  8,  0,  6, 10,  5,  8, 10,  0,  2, 13],
#        device='cuda:0'),
#  total  = 1584, correct = 276
# tensor([ 9,  1,  8,  4,  2, 10,  4,  5, 10, 10,  1,  1, 13,  1,  4,  3],
#        device='cuda:0')
# predicted = tensor([ 2,  9, 10,  5,  6,  2,  3, 10, 10,  2,  7,  2, 13,  9, 10, 10],
#        device='cuda:0'),
#  total  = 1600, correct = 278
# tensor([11, 12,  0,  4, 11, 10,  2,  4,  2,  8,  2,  8,  4,  3, 11, 11],
#        device='cuda:0')
# predicted = tensor([ 7, 11, 11,  3,  8, 10,  6, 13,  1, 10,  2,  8, 12,  8,  0,  8],
#        device='cuda:0'),
#  total  = 1616, correct = 281
# tensor([ 1, 10,  1, 11,  4,  1, 10,  5,  3, 12, 10,  0,  3,  9, 11, 10],
#        device='cuda:0')
# predicted = tensor([ 4,  0, 13,  7,  9,  3, 10,  2,  8, 11, 12,  1,  9,  2,  8, 10],
#        device='cuda:0'),
#  total  = 1632, correct = 283
# tensor([ 1, 11,  5, 10,  4,  3,  4,  9,  9, 12,  4, 11,  4,  3, 13,  9],
#        device='cuda:0')
# predicted = tensor([12,  0, 10, 10, 10,  0,  9,  1,  1,  9,  3,  0, 10,  0, 13, 13],
#        device='cuda:0'),
#  total  = 1648, correct = 285
# tensor([ 4, 13,  9,  4,  1, 10,  3,  6,  0,  0,  3,  8,  6,  2,  1, 10],
#        device='cuda:0')
# predicted = tensor([ 3, 13,  6,  3, 13,  6,  6,  3,  1,  5,  4,  9,  1,  3,  1,  2],
#        device='cuda:0'),
#  total  = 1664, correct = 287
# tensor([ 2,  4,  3,  3, 11,  7,  4, 10,  0,  2, 10,  5, 10, 11, 11,  5],
#        device='cuda:0')
# predicted = tensor([ 2,  6,  9,  9, 10, 10,  9,  2,  5,  6, 10,  5,  0, 11,  0,  0],
#        device='cuda:0'),
#  total  = 1680, correct = 291
# tensor([ 3, 10,  4,  2,  9,  1,  6,  2,  3, 11,  9,  6,  4,  3,  2, 13],
#        device='cuda:0')
# predicted = tensor([ 8,  0, 10,  4,  1,  2,  1,  2,  9,  8,  1, 10,  3,  9,  1, 13],
#        device='cuda:0'),
#  total  = 1696, correct = 293
# tensor([12,  6, 10,  0,  1,  0,  9,  6,  6, 10,  5, 11,  0,  3, 10, 11],
#        device='cuda:0')
# predicted = tensor([11,  3,  0, 13,  0,  1,  2,  5,  8, 12,  2,  8,  5,  4, 12, 11],
#        device='cuda:0'),
#  total  = 1712, correct = 294
# tensor([ 9,  0,  6,  0,  9, 10,  2,  5,  4,  6, 11,  1,  9,  1,  9,  5],
#        device='cuda:0')
# predicted = tensor([ 1, 11,  9,  3,  1, 12, 12,  2,  3,  8,  0,  4,  1,  1,  1,  2],
#        device='cuda:0'),
#  total  = 1728, correct = 295
# tensor([12,  3,  0, 13,  0,  6,  0, 10, 11,  7,  3, 10, 13,  8, 10,  4],
#        device='cuda:0')
# predicted = tensor([ 0, 10, 11, 13,  3, 13,  3,  2, 11,  5,  0, 10, 13,  9, 10,  3],
#        device='cuda:0'),
#  total  = 1744, correct = 300
# tensor([ 0, 13, 13,  0, 10, 11,  2,  1,  1, 13,  2, 10, 13,  6, 10, 11],
#        device='cuda:0')
# predicted = tensor([11, 13, 13, 11, 13,  0, 13,  1,  4, 13,  6,  2, 13,  6,  9,  0],
#        device='cuda:0'),
#  total  = 1760, correct = 306
# tensor([ 1,  9, 13, 12,  5, 11,  0,  3, 10, 12,  7,  2, 12,  9, 13,  6],
#        device='cuda:0')
# predicted = tensor([ 4,  1, 13,  3,  3, 11,  3,  4,  0,  8,  8, 12,  9,  2, 13,  1],
#        device='cuda:0'),
#  total  = 1776, correct = 309
# tensor([ 6,  4, 11,  8, 12, 11,  6, 12, 13,  6, 11,  8,  7,  2,  0,  0],
#        device='cuda:0')
# predicted = tensor([ 8,  3,  0, 10,  9, 11,  6,  8, 13,  8, 11,  8,  8,  2, 11,  1],
#        device='cuda:0'),
#  total  = 1792, correct = 315
# tensor([ 9, 10,  6,  6,  0, 10, 10,  4,  8,  7,  4,  4,  6,  0,  4,  6],
#        device='cuda:0')
# predicted = tensor([ 1, 10,  1,  8,  0, 13,  0,  9,  9,  0, 10, 10,  6, 11, 10,  8],
#        device='cuda:0'),
#  total  = 1808, correct = 318
# tensor([10,  3,  9,  6,  5, 10, 13, 12,  0,  5,  8, 10,  3,  3,  5, 11],
#        device='cuda:0')
# predicted = tensor([ 0,  0,  6,  1,  6,  0,  5,  8, 11, 10, 10,  4,  5,  0,  6,  8],
#        device='cuda:0'),
#  total  = 1824, correct = 318
# tensor([ 8, 11,  0, 10,  8,  6,  0,  5, 12,  0,  3, 11,  8,  0,  4, 10],
#        device='cuda:0')
# predicted = tensor([ 9, 11, 11,  0,  8,  8,  1,  2,  6, 11,  1,  7, 13,  9, 10,  2],
#        device='cuda:0'),
#  total  = 1840, correct = 320
# tensor([ 0,  2,  8, 10,  3,  6, 10,  5,  9,  6,  6,  4,  4,  4,  2, 11],
#        device='cuda:0')
# predicted = tensor([3, 2, 8, 0, 4, 8, 2, 2, 2, 9, 8, 3, 3, 9, 2, 8], device='cuda:0'),
#  total  = 1856, correct = 323
# tensor([11,  0, 11,  8,  3, 10,  1, 11, 11,  8, 12, 12,  4, 11,  2,  3],
#        device='cuda:0')
# predicted = tensor([11,  5,  7,  8,  5, 10,  3,  0, 11,  4,  9,  6,  3,  8,  0,  5],
#        device='cuda:0'),
#  total  = 1872, correct = 327
# tensor([ 6,  0,  4, 10,  5,  2,  8, 12, 11,  9,  8,  2,  5,  9,  6, 10],
#        device='cuda:0')
# predicted = tensor([ 1,  5,  5, 10,  2,  2,  8, 11, 13,  2,  5, 12,  0,  1,  1,  8],
#        device='cuda:0'),
#  total  = 1888, correct = 330
# tensor([10,  6,  5,  3, 10,  1,  3,  8,  3,  4,  2,  0,  6,  3,  5,  3],
#        device='cuda:0')
# predicted = tensor([ 2,  1,  2,  8, 10,  0,  5,  8,  8,  9,  6,  0,  3,  0, 12, 10],
#        device='cuda:0'),
#  total  = 1904, correct = 333
# tensor([13,  0,  3,  0,  6,  5,  9,  2, 11,  9, 10,  8, 11, 13, 12,  1],
#        device='cuda:0')
# predicted = tensor([13, 11,  5, 11,  8,  5,  1, 12, 11,  9,  4,  8, 11, 13, 11,  4],
#        device='cuda:0'),
#  total  = 1920, correct = 340
# tensor([ 3,  0, 10,  3,  6,  3,  3, 12,  9, 10, 11, 11,  2,  5,  0,  8],
#        device='cuda:0')
# predicted = tensor([10,  5,  2, 10,  6, 11,  4,  6,  2,  8,  8, 11,  2, 10,  3, 10],
#        device='cuda:0'),
#  total  = 1936, correct = 343
# tensor([ 3,  1,  6, 10,  6, 12, 10,  8, 10,  8,  8,  3,  6,  9,  8, 12],
#        device='cuda:0')
# predicted = tensor([ 4,  2,  6,  2,  0,  6,  2,  9, 13, 13, 11, 10,  5,  1,  8, 12],
#        device='cuda:0'),
#  total  = 1952, correct = 346
# tensor([ 2, 11,  1,  0,  2, 11,  9,  4, 10,  0,  1, 11, 10, 10,  3, 10],
#        device='cuda:0')
# predicted = tensor([ 0, 11,  2, 11,  9,  0, 13,  5,  0,  0,  9,  8,  2,  0, 10,  0],
#        device='cuda:0'),
#  total  = 1968, correct = 348
# tensor([ 0,  6,  9,  3, 13,  9,  8,  3, 10,  5,  4,  3,  6, 10,  7, 10],
#        device='cuda:0')
# predicted = tensor([11,  7,  9,  5,  0,  9,  6,  8, 12,  5,  3,  5,  6,  9,  5,  5],
#        device='cuda:0'),
#  total  = 1984, correct = 352
# tensor([ 8, 13, 12,  2, 11,  9, 10, 11,  4,  6, 10,  9,  1,  1,  6,  0],
#        device='cuda:0')
# predicted = tensor([10, 13, 11, 12,  8,  1, 10, 11, 10,  1, 10,  1,  3,  4, 11, 11],
#        device='cuda:0'),
#  total  = 2000, correct = 356
# tensor([ 0,  0, 10,  0,  4, 11,  1,  3,  9,  0, 10,  9,  3,  9,  5,  3],
#        device='cuda:0')
# predicted = tensor([ 5,  5,  2,  5,  5,  8,  0,  6,  2, 13, 12,  1,  1,  6, 13,  5],
#        device='cuda:0'),
#  total  = 2016, correct = 356
# tensor([12,  2, 10,  5,  6,  3,  9,  0,  4, 11,  4,  0,  4, 10,  7,  9],
#        device='cuda:0')
# predicted = tensor([ 8,  3,  0, 10,  6,  0,  2,  0,  5,  8,  9, 11,  6,  2, 11,  0],
#        device='cuda:0'),
#  total  = 2032, correct = 358
# tensor([13,  8,  9,  6,  4,  0,  3,  0, 13, 11,  3, 10, 13,  3,  9,  3],
#        device='cuda:0')
# predicted = tensor([13,  8,  6,  8,  3, 11,  9,  0, 13,  0,  5, 10, 13,  1,  1,  4],
#        device='cuda:0'),
#  total  = 2048, correct = 364
# tensor([ 0, 12,  7, 10,  6,  9,  9, 11,  8,  9,  5,  7,  9, 12,  9,  4],
#        device='cuda:0')
# predicted = tensor([11,  9,  7,  9,  3,  2,  2,  0,  8,  0,  5,  8,  6,  0,  0, 10],
#        device='cuda:0'),
#  total  = 2064, correct = 367
# tensor([ 1,  0,  5,  6,  8,  3,  4,  6,  8,  9, 10, 12, 10,  6,  7,  3],
#        device='cuda:0')
# predicted = tensor([ 9, 11, 10,  2,  9, 10, 10,  3, 13,  2,  4,  6, 12,  5,  9,  5],
#        device='cuda:0'),
#  total  = 2080, correct = 367
# tensor([ 1,  8,  9, 10,  2, 10,  6,  4,  6,  2,  1,  3,  9,  7,  3,  6],
#        device='cuda:0')
# predicted = tensor([ 0,  5,  2,  6, 12,  9,  6,  3,  2,  2,  0,  3,  1,  9,  9,  8],
#        device='cuda:0'),
#  total  = 2096, correct = 370
# tensor([ 6,  3, 13, 10,  0,  3, 13,  5, 12, 13,  4, 10,  2,  5,  5,  6],
#        device='cuda:0')
# predicted = tensor([ 6,  9, 13,  4,  1,  4, 13,  2,  3, 13,  3, 10, 11,  1, 12, 10],
#        device='cuda:0'),
#  total  = 2112, correct = 375
# tensor([10,  4,  5, 11, 13,  3,  8,  1,  7, 13, 11,  8,  6,  6,  6,  3],
#        device='cuda:0')
# predicted = tensor([10,  5,  2,  0, 13,  5,  9,  1, 10, 13,  7,  8,  8,  6,  8,  9],
#        device='cuda:0'),
#  total  = 2128, correct = 381
# tensor([ 4,  1, 10,  3, 10,  6,  1,  1, 10, 11,  4,  5, 13,  0,  1, 11],
#        device='cuda:0')
# predicted = tensor([ 3,  4,  0,  8,  5,  3,  0,  1,  0,  0,  3,  2, 13, 11,  0,  7],
#        device='cuda:0'),
#  total  = 2144, correct = 383
# tensor([ 3,  0, 11, 10, 12,  0,  9,  4,  6,  0, 10,  6,  6,  6, 13,  0],
#        device='cuda:0')
# predicted = tensor([ 5,  1, 11,  0, 12, 11,  1,  5,  1, 11, 10,  6,  2,  7,  5, 11],
#        device='cuda:0'),
#  total  = 2160, correct = 387
# tensor([13,  6, 12, 12,  3, 12,  1,  3, 12, 13, 13, 13,  6,  0,  9,  0],
#        device='cuda:0')
# predicted = tensor([13,  2,  5, 10,  4, 11,  1,  1,  0, 13, 13, 13,  1, 11,  6, 11],
#        device='cuda:0'),
#  total  = 2176, correct = 392
# tensor([ 4, 11, 11,  5,  2,  8,  6, 12, 11,  1, 12,  6,  5,  0,  5, 11],
#        device='cuda:0')
# predicted = tensor([13,  8, 11,  1, 13,  9,  1, 10,  7,  6,  9,  1,  5,  1,  8,  0],
#        device='cuda:0'),
#  total  = 2192, correct = 394
# tensor([ 3,  7,  6,  3, 10,  3, 12, 10,  4, 10,  4,  0,  0,  1, 10, 10],
#        device='cuda:0')
# predicted = tensor([ 8,  8,  5,  9,  9,  5,  9,  0,  3, 10,  3,  3,  3,  3,  0, 10],
#        device='cuda:0'),
#  total  = 2208, correct = 396
# tensor([ 3,  9,  5,  6,  1,  9,  4,  0,  2, 10,  5, 11, 10,  0,  4,  9],
#        device='cuda:0')
# predicted = tensor([ 5, 13, 13,  6,  2, 11,  3,  1,  2, 10,  5,  8, 10,  3,  3,  9],
#        device='cuda:0'),
#  total  = 2224, correct = 402
# tensor([10,  0,  2,  3,  0,  4, 10,  8,  1,  2,  3,  3,  6,  1,  1, 10],
#        device='cuda:0')
# predicted = tensor([ 2,  1, 12,  4, 11,  5, 12,  4,  9,  9,  4,  9,  1, 12,  9, 12],
#        device='cuda:0'),
#  total  = 2240, correct = 402
# tensor([ 4, 12, 12, 12,  1, 10,  5,  4,  1, 12,  3,  9,  5, 12, 12,  2],
#        device='cuda:0')
# predicted = tensor([ 9, 11, 11,  5,  9,  9,  5,  6,  9,  9,  4,  7,  2, 12,  6, 11],
#        device='cuda:0'),
#  total  = 2256, correct = 404
# tensor([ 6, 12,  4,  5,  0,  3, 11,  5,  3,  1,  1,  6, 10, 11, 11,  6],
#        device='cuda:0')
# predicted = tensor([ 8,  5,  9,  2,  0, 10, 11,  1,  1,  9,  0,  1,  0,  8, 11,  1],
#        device='cuda:0'),
#  total  = 2272, correct = 407
# tensor([11,  6,  1,  4,  0,  6,  4,  4,  8,  5,  3, 12,  5,  4,  4,  8],
#        device='cuda:0')
# predicted = tensor([ 8,  3, 10,  5,  3,  2,  5,  3,  6,  0,  4, 10,  2,  5,  3,  8],
#        device='cuda:0'),
#  total  = 2288, correct = 408
# tensor([ 0,  4,  3,  6,  4,  2,  3,  3,  0, 10,  2,  3,  8,  4,  3,  0],
#        device='cuda:0')
# predicted = tensor([12,  2, 10,  1,  3,  9,  5,  9,  5,  9,  6,  5, 10,  5,  8,  3],
#        device='cuda:0'),
#  total  = 2304, correct = 408
# tensor([ 0,  1, 11,  4,  9, 10,  5,  4, 13,  4, 12,  0,  5,  6,  7, 10],
#        device='cuda:0')
# predicted = tensor([ 0,  9,  8, 13,  9,  0, 10,  6, 13,  7,  3, 11,  2,  6,  8, 10],
#        device='cuda:0'),
#  total  = 2320, correct = 413
# tensor([ 8, 12,  1, 11,  8, 11,  0, 12,  4,  5,  7,  9,  5,  9,  9, 12],
#        device='cuda:0')
# predicted = tensor([ 8, 13,  3,  8,  8, 10,  3, 11,  5,  1,  8,  2,  2, 11,  9,  6],
#        device='cuda:0'),
#  total  = 2336, correct = 416
# tensor([13, 11,  0,  9,  6,  6, 10,  0, 10, 10, 12, 13,  0,  5,  1, 13],
#        device='cuda:0')
# predicted = tensor([13, 11,  5,  6,  2,  6, 10, 11,  2, 10,  8, 13,  1,  2,  9, 13],
#        device='cuda:0'),
#  total  = 2352, correct = 423
# tensor([11,  2, 10,  6,  0,  5,  0,  4, 11,  5,  9,  9,  9, 13,  6, 12],
#        device='cuda:0')
# predicted = tensor([11,  0, 10,  6,  3, 10,  0, 10,  7, 10,  6,  1,  1, 13,  0, 11],
#        device='cuda:0'),
#  total  = 2368, correct = 428
# tensor([ 6,  8,  6,  2, 10,  3,  2,  1,  9,  8, 11,  4,  6,  3, 13,  3],
#        device='cuda:0')
# predicted = tensor([ 2,  8,  8, 13, 10,  5,  3,  5,  9,  8,  0,  3,  2,  9, 13,  9],
#        device='cuda:0'),
#  total  = 2384, correct = 433
# tensor([11,  0, 11,  9,  9,  9,  9,  3,  2, 10, 10,  4,  6,  3, 10, 11],
#        device='cuda:0')
# predicted = tensor([ 0, 11,  8,  2,  1,  1,  9,  9,  6, 10,  9,  3,  6,  9,  2,  8],
#        device='cuda:0'),
#  total  = 2400, correct = 436
# tensor([ 5,  6, 13, 10,  9,  0, 12,  3,  8,  5,  0, 12,  1, 13,  1, 12],
#        device='cuda:0')
# predicted = tensor([ 3,  0, 13, 10,  7,  1, 10, 10,  9,  6, 11,  5,  9, 13,  0, 12],
#        device='cuda:0'),
#  total  = 2416, correct = 440
# tensor([ 0, 12,  5, 13,  2,  2,  8,  9,  1,  6,  6, 11,  3, 12,  1, 10],
#        device='cuda:0')
# predicted = tensor([ 3, 13, 10,  1,  6,  6,  9,  2,  3,  0,  8, 11, 10, 11, 13, 12],
#        device='cuda:0'),
#  total  = 2432, correct = 441
# tensor([ 5, 12,  0,  1,  3,  5,  4, 10,  5,  6,  2,  9, 13, 11,  3,  4],
#        device='cuda:0')
# predicted = tensor([10, 10, 11,  3,  5,  6,  5,  9, 13,  1,  6,  9, 13,  0,  9,  5],
#        device='cuda:0'),
#  total  = 2448, correct = 443
# tensor([10,  3, 12,  9,  3,  2,  3, 11,  6,  1,  4,  6,  3,  4,  6, 13],
#        device='cuda:0')
# predicted = tensor([ 0, 10, 12,  2,  9,  1,  9,  8,  8,  4,  5,  8,  4,  5,  8, 13],
#        device='cuda:0'),
#  total  = 2464, correct = 445
# tensor([ 6,  1, 12,  7,  3,  0,  1,  3,  4,  6, 11,  3, 11, 13,  3, 10],
#        device='cuda:0')
# predicted = tensor([ 5,  8,  9, 10,  9,  1, 13, 10,  3,  6, 11, 10,  8,  5,  4,  9],
#        device='cuda:0'),
#  total  = 2480, correct = 447
# tensor([ 0,  9, 11, 11, 10,  1, 10,  9,  0,  6,  6,  1,  1,  9, 10,  0],
#        device='cuda:0')
# predicted = tensor([ 3,  6,  0,  6,  9,  0, 10,  1, 11,  1,  6,  2, 10,  1,  8,  1],
#        device='cuda:0'),
#  total  = 2496, correct = 449
# tensor([ 0,  3, 11, 10,  5, 10,  6,  7,  6,  4,  0,  0,  8,  5,  8,  5],
#        device='cuda:0')
# predicted = tensor([ 5,  1,  0, 12,  6,  0,  6,  5,  1,  3,  5,  1,  8, 12, 13,  2],
#        device='cuda:0'),
#  total  = 2512, correct = 451
# tensor([ 1, 13,  9,  4,  9,  9,  9,  3, 13,  1, 13,  2,  0,  0, 12,  3],
#        device='cuda:0')
# predicted = tensor([13, 13,  1,  3, 13,  2,  1,  9, 13,  4,  5,  6, 11,  5,  6,  9],
#        device='cuda:0'),
#  total  = 2528, correct = 453
# tensor([ 7,  1,  0,  0,  1,  9, 13, 13,  6,  3,  6,  9,  6, 10, 10, 13],
#        device='cuda:0')
# predicted = tensor([11,  9,  3, 11, 13,  2, 13, 13, 10,  1,  8, 13,  3, 10,  2, 12],
#        device='cuda:0'),
#  total  = 2544, correct = 456
# tensor([13,  9,  7,  3,  5, 13, 12,  9,  8,  0,  1,  5, 11, 10,  5, 11],
#        device='cuda:0')
# predicted = tensor([ 5,  9,  8,  4,  2, 13,  8,  9, 10,  0,  1,  6,  0,  9,  2,  0],
#        device='cuda:0'),
#  total  = 2560, correct = 461
# tensor([10,  0, 11, 10,  6,  5,  3,  9,  2, 11, 11,  5, 10, 11, 13,  8],
#        device='cuda:0')
# predicted = tensor([ 2,  3,  0, 10,  1,  5,  0,  1, 13, 11, 11, 10,  4,  8, 13, 10],
#        device='cuda:0'),
#  total  = 2576, correct = 466
# tensor([13,  4,  0, 11,  6,  9,  8,  6,  1, 13,  4,  2,  4,  3, 11,  6],
#        device='cuda:0')
# predicted = tensor([13,  5,  5,  8,  1,  9,  9,  5, 13,  5, 10, 13,  9,  8,  2,  5],
#        device='cuda:0'),
#  total  = 2592, correct = 468
# tensor([ 4,  0,  3, 10,  8,  4,  0,  9,  3,  5,  6,  5,  9, 10, 12,  2],
#        device='cuda:0')
# predicted = tensor([ 5, 11,  5, 10, 13,  5,  3,  1,  9, 11, 10, 10,  6,  0, 11,  3],
#        device='cuda:0'),
#  total  = 2608, correct = 469
# tensor([10,  5,  5, 12,  3,  3, 13,  6,  3,  6,  2, 13, 11,  1,  3,  6],
#        device='cuda:0')
# predicted = tensor([10,  2,  3,  6,  4,  4, 13,  1,  1,  6,  1, 13, 10, 13, 10,  6],
#        device='cuda:0'),
#  total  = 2624, correct = 474
# tensor([11,  9,  6,  9,  3,  6,  5,  6,  3,  2, 13,  6,  8,  6,  3,  4],
#        device='cuda:0')
# predicted = tensor([11,  2,  1,  1,  0,  8, 12,  1,  1, 10, 13,  1, 10,  2,  4,  3],
#        device='cuda:0'),
#  total  = 2640, correct = 476
# tensor([ 6,  6,  9, 10,  0,  0,  2,  4,  3, 13, 10,  1,  1, 11,  4,  3],
#        device='cuda:0')
# predicted = tensor([ 1,  5,  2,  0,  0, 11,  6,  3,  0, 13, 10,  0, 10,  8,  3,  8],
#        device='cuda:0'),
#  total  = 2656, correct = 479
# tensor([ 3, 10,  1, 13, 11, 11,  5, 10,  6,  2,  9,  9,  1,  3, 11,  9],
#        device='cuda:0')
# predicted = tensor([10, 10,  9, 13, 11,  7,  2,  4,  6,  9,  9, 10,  9, 13,  8,  1],
#        device='cuda:0'),
#  total  = 2672, correct = 484
# tensor([ 6,  5,  0, 13, 12,  1,  0, 13,  0, 11,  8,  2,  1,  7,  1, 10],
#        device='cuda:0')
# predicted = tensor([ 8, 12,  0, 13,  6,  9,  5, 13,  1, 11, 11,  6,  8,  8, 12,  4],
#        device='cuda:0'),
#  total  = 2688, correct = 488
# tensor([ 6, 13,  6,  4,  1,  6,  0, 13, 12, 11,  6, 13,  2, 11,  3,  2],
#        device='cuda:0')
# predicted = tensor([ 2, 13,  8,  3,  9,  8,  4,  5,  8,  0,  8, 13, 13, 11, 10,  1],
#        device='cuda:0'),
#  total  = 2704, correct = 491
# tensor([ 3,  9, 11, 11, 11, 11,  5,  7, 10,  2,  0, 10,  9,  5, 12, 10],
#        device='cuda:0')
# predicted = tensor([ 5,  6,  7,  0,  0,  0, 10,  8,  2,  3,  3,  0,  0,  3,  8,  2],
#        device='cuda:0'),
#  total  = 2720, correct = 491
# tensor([11, 10,  5,  1,  4, 11,  6,  4, 10,  0, 10, 12,  1,  4,  2,  9],
#        device='cuda:0')
# predicted = tensor([ 0,  0,  2,  2,  5,  8,  8,  3,  0,  0, 12, 11,  0,  5,  2,  1],
#        device='cuda:0'),
#  total  = 2736, correct = 493
# tensor([ 5,  3, 10, 10,  9, 10,  5, 12,  6,  6,  9,  5,  3,  3,  0,  0],
#        device='cuda:0')
# predicted = tensor([ 2,  8,  9,  8,  1, 10,  8, 12,  8,  2,  2,  1,  8,  8,  5,  5],
#        device='cuda:0'),
#  total  = 2752, correct = 495
# tensor([ 3, 11,  2,  6,  6, 10,  5,  3,  0, 11, 11,  4,  5,  9, 10, 11],
#        device='cuda:0')
# predicted = tensor([13,  0,  2,  8,  8,  2,  3, 10, 11, 11,  8, 12,  6,  6,  9,  8],
#        device='cuda:0'),
#  total  = 2768, correct = 497
# tensor([ 0,  9,  6,  3,  8, 13,  0,  3,  6,  5, 11,  8,  3,  1,  5,  8],
#        device='cuda:0')
# predicted = tensor([ 1,  2,  8,  0,  9, 13,  0, 13, 10,  2,  8, 13,  9,  0,  6,  8],
#        device='cuda:0'),
#  total  = 2784, correct = 500
# tensor([ 4,  7,  2,  4, 11,  0,  9,  3,  3,  1, 11,  4, 11,  6,  3,  1],
#        device='cuda:0')
# predicted = tensor([10,  9,  2,  5, 11,  0, 10,  4,  5,  4, 11, 10,  8, 10,  0,  2],
#        device='cuda:0'),
#  total  = 2800, correct = 504
# tensor([12,  5,  8,  3,  6,  3,  2, 11,  6,  7,  6,  4,  6,  6,  5,  0],
#        device='cuda:0')
# predicted = tensor([11,  5,  8,  8,  8,  5,  9,  7,  6,  8,  1,  5,  1,  6,  5,  0],
#        device='cuda:0'),
#  total  = 2816, correct = 510
# tensor([ 1, 10, 12,  3,  0,  6,  9,  8,  1, 12,  2,  1, 10,  6, 12,  8],
#        device='cuda:0')
# predicted = tensor([ 9,  0, 11,  8, 11,  8,  1,  9,  0,  0,  6, 12, 10,  6, 11,  6],
#        device='cuda:0'),
#  total  = 2832, correct = 512
# tensor([10,  1,  5,  8, 12, 13,  6,  2,  7, 10, 10,  2, 12,  6,  6,  0],
#        device='cuda:0')
# predicted = tensor([ 4,  3, 10,  8, 12, 13,  1, 12, 10, 10, 10,  6,  1,  8,  1,  3],
#        device='cuda:0'),
#  total  = 2848, correct = 517
# tensor([ 9,  1,  6,  3, 12,  1,  0,  2,  3,  9,  0, 11,  4, 10, 13,  3],
#        device='cuda:0')
# predicted = tensor([ 1,  3,  1,  8,  5,  1,  0, 11,  1,  9,  1,  2,  5,  0, 13, 10],
#        device='cuda:0'),
#  total  = 2864, correct = 521
# tensor([ 6,  4,  6, 10,  4,  1,  7,  0,  9,  1,  4,  5,  3, 12,  6,  6],
#        device='cuda:0')
# predicted = tensor([ 0,  6,  1, 10, 13,  3,  8,  3,  2,  8,  9, 12,  4,  5,  1,  3],
#        device='cuda:0'),
#  total  = 2880, correct = 522
# tensor([ 6, 13,  8,  0,  4, 10,  6, 11,  6, 11, 11,  1, 13,  0,  3, 12],
#        device='cuda:0')
# predicted = tensor([ 1, 13,  8,  1,  5, 10,  8,  0,  1,  2,  8,  4, 13,  0,  5, 11],
#        device='cuda:0'),
#  total  = 2896, correct = 527
# tensor([11,  6,  0,  2,  6,  9, 10,  8, 10,  6,  7,  5,  8, 13, 12,  6],
#        device='cuda:0')
# predicted = tensor([10,  8,  1,  5,  5,  2,  2,  9,  0,  1,  8,  2,  8, 13,  6,  8],
#        device='cuda:0'),
#  total  = 2912, correct = 529
# tensor([ 5,  5,  5,  6,  6,  0,  4,  6,  1,  5,  6, 10,  0, 13, 13,  2],
#        device='cuda:0')
# predicted = tensor([ 2, 12,  0,  8,  3,  3,  9,  1,  7,  2,  1,  0,  0, 13, 13, 10],
#        device='cuda:0'),
#  total  = 2928, correct = 532
# tensor([ 6, 11,  0, 10,  0,  4,  7,  9,  6, 13, 12, 12, 13,  9, 13, 10],
#        device='cuda:0')
# predicted = tensor([ 2,  7, 11, 10,  3, 10,  9, 13,  2, 13,  1, 11,  0,  1,  5,  8],
#        device='cuda:0'),
#  total  = 2944, correct = 534
# tensor([ 1, 10,  2,  2, 10, 10, 10, 11,  5,  0,  3,  9, 11,  1,  4, 10],
#        device='cuda:0')
# predicted = tensor([ 9,  0,  3,  6,  0,  8,  0,  0, 13,  0,  4,  9, 10, 12,  9,  6],
#        device='cuda:0'),
#  total  = 2960, correct = 536
# tensor([ 9,  9,  9, 10,  5, 10, 10,  5,  5,  4, 12, 12,  1, 13,  4,  3],
#        device='cuda:0')
# predicted = tensor([ 1,  8,  1,  2, 10,  6,  2,  5,  2,  5,  9, 11,  3, 13,  5,  5],
#        device='cuda:0'),
#  total  = 2976, correct = 538
# tensor([ 1,  3, 10,  0, 10, 11, 13,  5,  3,  2, 12,  6,  0,  5,  6, 13],
#        device='cuda:0')
# predicted = tensor([ 3,  8, 10, 11, 12,  8, 13,  5,  1,  6,  5,  8,  5, 10,  1, 13],
#        device='cuda:0'),
#  total  = 2992, correct = 542
# tensor([ 3, 12,  9,  6,  0,  1,  9, 10, 10,  6,  6,  4,  3,  3,  3,  9],
#        device='cuda:0')
# predicted = tensor([ 5,  6,  6,  8,  3, 12,  1,  6,  2,  6,  3,  3,  5,  4, 13,  6],
#        device='cuda:0'),
#  total  = 3008, correct = 543
# tensor([ 1,  3,  4,  8, 11, 10,  5, 10, 11,  5, 10,  1,  0,  4,  6,  5],
#        device='cuda:0')
# predicted = tensor([11,  0, 12,  8, 11,  6, 12,  9,  8,  6,  6,  5, 11,  5,  6,  6],
#        device='cuda:0'),
#  total  = 3024, correct = 546
# tensor([ 6,  0,  4,  6,  6,  8, 13,  6,  0,  6, 12,  9,  3, 10,  4,  9],
#        device='cuda:0')
# predicted = tensor([ 3, 13,  9,  6,  6, 10, 13,  6,  0,  0, 12,  1,  5,  8,  9,  6],
#        device='cuda:0'),
#  total  = 3040, correct = 552
# tensor([ 8,  8,  6,  9, 12, 11,  8,  2,  0,  0,  6,  1,  3,  1, 12,  5],
#        device='cuda:0')
# predicted = tensor([13, 10,  8,  1,  5,  7,  8, 10,  1, 13,  1,  9,  1,  1,  5, 10],
#        device='cuda:0'),
#  total  = 3056, correct = 554
# tensor([ 3, 13,  6, 10,  5,  2, 13,  1,  0,  4,  2,  3,  1,  6, 12,  9],
#        device='cuda:0')
# predicted = tensor([ 4, 13,  5, 12,  5,  2, 12,  1,  0,  5,  3,  6,  4,  8, 10,  6],
#        device='cuda:0'),
#  total  = 3072, correct = 559
# tensor([ 6,  6, 11,  2, 10,  9,  2, 10,  3,  6, 11,  0,  1,  4,  4, 11],
#        device='cuda:0')
# predicted = tensor([ 0,  8, 10,  6,  4,  1,  2,  2, 13,  6,  8,  3, 13,  3,  5,  0],
#        device='cuda:0'),
#  total  = 3088, correct = 561
# tensor([10,  4, 11, 10,  4,  1,  3,  3,  6,  2,  3, 12,  4,  2,  0,  0],
#        device='cuda:0')
# predicted = tensor([ 9,  9,  2,  0,  3, 13,  5, 10,  1, 12,  9, 11, 10,  6,  1,  3],
#        device='cuda:0'),
#  total  = 3104, correct = 561
# tensor([ 9,  9, 10,  9,  9,  5, 12,  3,  0,  1,  0,  3, 12,  5,  4,  6],
#        device='cuda:0')
# predicted = tensor([ 1, 13, 13, 13,  2,  6,  3,  5, 13,  3,  1,  4,  6,  5,  9,  3],
#        device='cuda:0'),
#  total  = 3120, correct = 562
# tensor([ 5,  9,  9,  7, 12,  6, 11,  6,  3,  6,  9,  9,  2,  4,  2,  3],
#        device='cuda:0')
# predicted = tensor([10,  0,  2, 12,  1,  1, 10,  5,  5,  1,  9,  1, 13,  5, 12,  6],
#        device='cuda:0'),
#  total  = 3136, correct = 563
# tensor([ 3, 11,  4,  3, 10,  1, 11,  2, 13, 10,  6,  1,  0, 13,  0,  0],
#        device='cuda:0')
# predicted = tensor([ 3, 11,  5, 10, 10,  8,  8,  2, 13, 10,  8,  4, 11, 13,  0, 11],
#        device='cuda:0'),
#  total  = 3152, correct = 571
# tensor([ 4, 12, 11,  0, 12,  2, 11,  9,  1,  3,  0, 10,  3,  3, 10, 11],
#        device='cuda:0')
# predicted = tensor([ 3, 12,  5, 13,  9,  2,  0,  1,  0,  8, 11, 10, 13,  4,  9,  8],
#        device='cuda:0'),
#  total  = 3168, correct = 574
# tensor([ 2,  6, 13,  9,  6,  8,  0,  7,  5, 10,  1, 10,  6, 11,  1,  4],
#        device='cuda:0')
# predicted = tensor([ 6,  6, 13,  2,  8,  9,  1,  3,  9,  4,  1, 13,  8,  8,  8,  9],
#        device='cuda:0'),
#  total  = 3184, correct = 577
# tensor([ 3,  5, 13, 13, 13,  1,  4,  0, 12,  0,  2,  9,  4, 13,  3, 11],
#        device='cuda:0')
# predicted = tensor([ 3,  2, 13, 12, 13, 12,  5,  5, 11,  3,  0,  6,  9, 13,  0, 11],
#        device='cuda:0'),
#  total  = 3200, correct = 582
# tensor([ 0,  0, 10,  4,  0,  3,  0,  0, 12,  3, 13,  4,  0,  2,  2,  7],
#        device='cuda:0')
# predicted = tensor([11, 11, 12,  5,  1,  0, 11,  0,  6, 10, 13,  5,  3, 12,  3,  5],
#        device='cuda:0'),
#  total  = 3216, correct = 584
# tensor([ 2,  3,  2, 12,  5, 10,  2, 11,  6, 13, 13,  3,  0,  5,  0,  1],
#        device='cuda:0')
# predicted = tensor([12,  8,  2, 11,  2, 10, 12,  7,  2,  5, 13,  4, 11,  6,  5,  6],
#        device='cuda:0'),
#  total  = 3232, correct = 587
# tensor([ 6,  3,  0,  4, 11,  7,  2,  3,  2,  1,  0,  0,  8,  3,  1,  5],
#        device='cuda:0')
# predicted = tensor([11,  9, 11, 10, 10,  8,  6, 10, 12,  6,  0, 13, 10,  9, 10, 12],
#        device='cuda:0'),
#  total  = 3248, correct = 588
# ...
#        device='cuda:0'),
#  total  = 9536, correct = 1718
# tensor([ 2,  1,  1,  5,  3,  2,  6,  0, 10,  9,  5,  8, 13, 11, 10, 12],
#        device='cuda:0')
# predicted = tensor([ 2, 12,  2, 10,  9, 12,  1, 11,  4,  2,  9,  8,  5,  8, 10,  6],
#        device='cuda:0'),
#  total  = 9552, correct = 1721
# tensor([ 6,  4, 11,  3,  6, 11,  5,  6, 12,  0,  1, 11,  0,  4, 13, 11],
#        device='cuda:0')
# predicted = tensor([ 8,  5, 11,  3,  8, 11,  5,  1,  8,  3,  9, 11, 11,  9, 12,  8],
#        device='cuda:0'),
#  total  = 9568, correct = 1726
# tensor([13, 10,  3,  0, 13,  1,  9, 10,  9,  4, 13,  4, 12,  2,  4,  3],
#        device='cuda:0')
# predicted = tensor([13,  4,  4,  3, 13,  4,  1, 12,  1,  1, 13,  9, 11,  1,  3, 13],
#        device='cuda:0'),
#  total  = 9584, correct = 1729
# tensor([ 3,  3,  3, 11, 10,  4, 11,  1,  4,  4,  3,  2, 12,  9,  6,  4],
#        device='cuda:0')
# predicted = tensor([ 3,  8, 10, 10, 12,  0, 11,  0, 13,  2,  8,  9,  8,  9, 11, 12],
#        device='cuda:0'),
#  total  = 9600, correct = 1732
# tensor([10,  3,  3, 12,  4,  5,  6,  5,  0, 10,  3, 13,  4,  9, 10, 10],
#        device='cuda:0')
# predicted = tensor([ 9,  6,  4,  6,  9,  2,  8,  6,  0, 12,  6, 13,  3,  2,  0,  6],
#        device='cuda:0'),
#  total  = 9616, correct = 1734
# tensor([ 1,  7,  6,  9,  0,  6, 12,  3,  9,  2,  6,  3,  5,  9,  6,  8],
#        device='cuda:0')
# predicted = tensor([13,  8,  8,  9,  0,  3, 11,  6,  2,  3,  8,  4,  5,  2,  1,  8],
#        device='cuda:0'),
#  total  = 9632, correct = 1738
# tensor([ 8,  7, 10,  9,  6, 10,  9,  7,  6, 13, 13,  5,  6, 13,  9,  3],
#        device='cuda:0')
# predicted = tensor([10,  8, 10,  2,  1,  5,  2,  5,  9, 13, 13,  8,  6, 13,  2,  4],
#        device='cuda:0'),
#  total  = 9648, correct = 1743
# tensor([ 8,  5,  7, 11,  1,  0, 13,  0,  9, 10,  1, 10, 11,  0,  5, 10],
#        device='cuda:0')
# predicted = tensor([11,  2,  9,  0,  9,  1, 13,  3,  1,  2, 13,  2,  8,  1,  6, 10],
#        device='cuda:0'),
#  total  = 9664, correct = 1745
# tensor([ 1,  0, 10, 10, 13,  4,  4,  5,  6, 13,  1,  6, 12,  5,  4,  0],
#        device='cuda:0')
# predicted = tensor([ 9,  1, 12, 13, 13, 10, 10,  6,  6,  5,  9,  9,  6,  3,  3,  0],
#        device='cuda:0'),
#  total  = 9680, correct = 1748
# tensor([ 6,  0,  5,  1,  8, 10,  6, 10,  1,  9,  4,  0,  8, 11,  4,  3],
#        device='cuda:0')
# predicted = tensor([ 1, 11, 12,  0, 10,  4,  1,  0, 12,  2,  5,  1, 10,  0,  5,  1],
#        device='cuda:0'),
#  total  = 9696, correct = 1748
# tensor([ 4,  6,  0,  0,  6, 11,  4,  7, 13,  6, 10,  6, 10,  6, 10,  2],
#        device='cuda:0')
# predicted = tensor([ 5,  6, 10,  1,  0, 11,  5,  8, 13,  6,  0,  8, 10,  8, 10,  2],
#        device='cuda:0'),
#  total  = 9712, correct = 1755
# tensor([11,  9, 13, 13,  6,  0,  0,  6,  3,  0,  6, 10,  9,  9, 13, 10],
#        device='cuda:0')
# predicted = tensor([ 0,  1, 13, 13,  6,  3,  5,  6,  8,  9,  5, 10,  1,  2, 13,  2],
#        device='cuda:0'),
#  total  = 9728, correct = 1761
# tensor([ 3,  3, 11, 12,  6,  0, 11,  6,  6, 10,  7,  7,  3,  2, 11, 13],
#        device='cuda:0')
# predicted = tensor([ 4,  4,  0,  6,  8,  3,  0, 10,  8,  6,  8, 10, 10,  6,  8, 13],
#        device='cuda:0'),
#  total  = 9744, correct = 1762
# tensor([ 1,  9,  9,  3,  1, 10,  5,  9,  4,  9,  4,  9,  6, 13,  0,  9],
#        device='cuda:0')
# predicted = tensor([ 1,  6,  1, 11,  3, 13,  5,  2,  3,  9,  9,  1,  1, 13,  0,  2],
#        device='cuda:0'),
#  total  = 9760, correct = 1767
# tensor([13,  1, 11,  9,  2,  0,  5,  9, 10,  8, 11,  6, 10, 11,  9, 11],
#        device='cuda:0')
# predicted = tensor([13,  1,  8,  1,  2,  1,  1,  9,  0,  8, 11,  8,  4, 11,  9, 11],
#        device='cuda:0'),
#  total  = 9776, correct = 1776
# tensor([ 5, 13,  8, 13,  4,  0,  6,  3,  9,  0,  2, 12,  3,  5,  5, 10],
#        device='cuda:0')
# predicted = tensor([ 1, 13,  8, 13,  5,  3, 13,  5,  1,  3,  2, 12,  0, 10,  5,  8],
#        device='cuda:0'),
#  total  = 9792, correct = 1782
# tensor([ 0,  6,  5,  3,  1,  3,  6,  3,  6,  6,  0,  3, 10,  1,  1, 11],
#        device='cuda:0')
# predicted = tensor([ 3,  8,  5, 13,  4,  1,  8,  5,  6,  1,  3,  8,  0,  9,  0,  8],
#        device='cuda:0'),
#  total  = 9808, correct = 1784
# tensor([ 6,  2,  5,  9,  3,  8,  3,  6, 11, 11, 11,  7,  4,  0,  9,  5],
#        device='cuda:0')
# predicted = tensor([ 8,  9, 13,  6,  4,  9,  8,  2,  0,  8, 11,  8,  9,  3,  1, 10],
#        device='cuda:0'),
#  total  = 9824, correct = 1785
# tensor([ 8,  8,  4, 12, 10, 11,  6,  0, 11,  6, 13, 10,  4,  1,  0, 12],
#        device='cuda:0')
# predicted = tensor([ 8,  8,  3, 11, 10,  0,  8,  3, 11,  8, 12,  4,  1,  0,  1,  6],
#        device='cuda:0'),
#  total  = 9840, correct = 1789
# tensor([ 6, 10, 10,  4,  8, 12,  4,  6,  6, 13,  3, 10,  9, 10, 11,  6],
#        device='cuda:0')
# predicted = tensor([ 1,  0,  5, 12, 11,  8, 10,  1,  1, 13,  0, 12,  9, 13, 11,  8],
#        device='cuda:0'),
#  total  = 9856, correct = 1792
# tensor([ 4,  3,  8, 13,  2, 11, 13,  1,  1,  4,  2,  6,  9,  2,  9,  3],
#        device='cuda:0')
# predicted = tensor([ 3,  3, 10, 13, 13, 11, 13,  4,  4,  3,  6, 11,  9,  5, 13,  3],
#        device='cuda:0'),
#  total  = 9872, correct = 1798
# tensor([ 8,  1,  3,  6,  8,  9,  2, 13,  6,  9,  4, 10, 12,  2,  9,  4],
#        device='cuda:0')
# predicted = tensor([ 8,  0,  4,  1,  8,  9,  2,  5,  8,  6, 10,  9, 11,  0,  1,  5],
#        device='cuda:0'),
#  total  = 9888, correct = 1802
# tensor([ 1, 11,  4,  4, 12, 10, 12,  0,  1, 11,  1,  6,  6, 10,  6, 10],
#        device='cuda:0')
# predicted = tensor([ 3, 11,  3,  5, 12, 10,  9, 11,  1,  8,  9,  6, 10, 13,  0, 12],
#        device='cuda:0'),
#  total  = 9904, correct = 1807
# tensor([12,  4,  1, 10,  9, 10,  5, 11,  0,  0,  4, 11, 11,  4, 10,  7],
#        device='cuda:0')
# predicted = tensor([ 5,  5,  3,  5,  0,  0,  5,  8,  3,  1, 10, 11,  0,  5,  8,  8],
#        device='cuda:0'),
#  total  = 9920, correct = 1809
# tensor([13,  0,  4,  5,  2,  6,  9,  3,  6,  8, 10, 10, 13, 12, 10,  7],
#        device='cuda:0')
# predicted = tensor([13,  1,  9, 10,  2,  7,  0,  4,  6,  8, 12, 10, 13, 11, 10,  8],
#        device='cuda:0'),
#  total  = 9936, correct = 1816
# tensor([ 6,  0,  1,  8, 11, 11,  3,  1, 11,  5, 11,  2,  9,  0, 11,  0],
#        device='cuda:0')
# predicted = tensor([ 5, 11,  3,  9,  0,  8,  0,  4, 10,  5,  0,  6,  1, 13,  8,  5],
#        device='cuda:0'),
#  total  = 9952, correct = 1817
# tensor([ 6,  6, 10, 11, 12,  5,  9,  3,  1, 12,  0, 13, 13, 12,  2,  0],
#        device='cuda:0')
# predicted = tensor([10,  8, 13, 11,  8, 12, 13,  5,  4, 11,  0, 13, 13,  6,  2, 11],
#        device='cuda:0'),
#  total  = 9968, correct = 1822
# tensor([ 7,  5,  1, 12,  5,  2, 10, 10,  6, 10,  5, 10, 10, 10, 12,  6],
#        device='cuda:0')
# predicted = tensor([ 8, 13,  0,  8,  1,  1,  2,  2,  1,  0,  2,  2, 10,  0,  8,  1],
#        device='cuda:0'),
#  total  = 9984, correct = 1823
# tensor([ 0,  9,  6,  0,  8,  4,  1,  1,  5,  5,  6,  0,  2,  0, 11,  9],
#        device='cuda:0')
# predicted = tensor([ 0,  0, 10,  5, 10,  9,  0,  0,  6,  0,  8,  9,  0,  3,  7,  1],
#        device='cuda:0'),
#  total  = 10000, correct = 1824
# tensor([ 9, 13,  4,  2,  2, 10,  1,  2, 11, 11, 10,  7, 10, 11,  5,  2],
#        device='cuda:0')
# predicted = tensor([13, 13,  3,  9, 13, 10, 13, 12,  8,  0, 12, 10,  0,  7,  5,  2],
#        device='cuda:0'),
#  total  = 10016, correct = 1828
# tensor([ 2,  0,  2,  9, 11,  8,  6,  6,  1,  4,  6,  8,  1,  6,  9, 11],
#        device='cuda:0')
# predicted = tensor([ 4,  3,  1,  6, 11, 11,  0,  8,  0,  3,  9, 10,  9,  1,  9,  0],
#        device='cuda:0'),
#  total  = 10032, correct = 1830
# tensor([10, 12,  3,  5,  3,  5,  6, 12,  6,  3, 11,  3, 10, 10, 10,  3],
#        device='cuda:0')
# predicted = tensor([13,  5,  8, 12,  8,  1,  1,  8,  8,  1, 11,  9,  9,  2, 10,  8],
#        device='cuda:0'),
#  total  = 10048, correct = 1832
# tensor([ 0,  1,  1,  3,  6,  9,  8,  0,  3,  6, 10,  1,  5,  4,  1,  1],
#        device='cuda:0')
# predicted = tensor([ 5,  0,  9, 10,  6,  0, 10, 11,  9,  1, 10,  0,  2,  3,  4,  8],
#        device='cuda:0'),
#  total  = 10064, correct = 1834
# tensor([13,  9,  8,  3,  1,  6,  9, 10,  3,  6,  0,  3, 12,  4,  1, 10],
#        device='cuda:0')
# predicted = tensor([13,  1,  8,  5,  2,  8,  1, 13,  5,  5,  0,  8,  6,  3, 13, 10],
#        device='cuda:0'),
#  total  = 10080, correct = 1838
# tensor([ 2,  6, 10,  8,  9,  6,  4,  6, 12, 12,  2, 11,  2,  9,  6,  3],
#        device='cuda:0')
# predicted = tensor([ 2,  8,  2, 13,  1,  8,  5,  5,  6, 11,  6,  0, 12,  9, 10,  1],
#        device='cuda:0'),
#  total  = 10096, correct = 1840
# tensor([13,  6,  2, 12,  6,  4,  2,  2,  0,  9, 10,  0, 13, 13,  3,  5],
#        device='cuda:0')
# predicted = tensor([13,  1,  6, 10,  6,  5,  6, 12,  3,  1, 11, 11,  0, 13,  3, 10],
#        device='cuda:0'),
#  total  = 10112, correct = 1844
# tensor([ 9, 11,  3,  2,  8,  9,  0, 11,  6,  8, 11,  4,  3,  5,  5,  5],
#        device='cuda:0')
# predicted = tensor([ 1, 10,  8,  2, 10,  8,  1,  8,  8,  8, 11,  9,  1,  2, 10, 10],
#        device='cuda:0'),
#  total  = 10128, correct = 1847
# tensor([ 3,  8,  3, 10,  5,  7,  9,  6,  1,  9,  3,  3,  2, 13,  4,  0],
#        device='cuda:0')
# predicted = tensor([ 3, 13, 10,  0,  6,  8,  9,  1,  1,  2, 13,  0,  0, 13,  9,  5],
#        device='cuda:0'),
#  total  = 10144, correct = 1851
# tensor([ 3, 10,  1, 12,  1,  0, 13,  4, 11,  8,  0,  2,  6,  0, 12,  5],
#        device='cuda:0')
# predicted = tensor([13,  2, 10,  4,  9,  0, 13,  5,  0, 13, 11, 12,  5,  9, 11,  6],
#        device='cuda:0'),
#  total  = 10160, correct = 1853
# tensor([12,  2,  0, 12,  4,  6,  3, 11,  1, 10, 11,  5,  9, 13,  1,  6],
#        device='cuda:0')
# predicted = tensor([ 9, 12,  5,  9,  5,  3,  5, 10,  0, 13,  8, 10,  6, 13,  1,  0],
#        device='cuda:0'),
#  total  = 10176, correct = 1855
# tensor([ 1,  9,  1,  0,  3,  5, 10, 11,  5,  0,  4,  5,  5, 12,  0,  6],
#        device='cuda:0')
# predicted = tensor([ 1,  1, 13,  3,  9,  9, 12,  8, 10,  1,  5, 13,  5, 11,  0,  6],
#        device='cuda:0'),
#  total  = 10192, correct = 1859
# tensor([ 6,  4,  0, 10,  3, 11,  2,  1, 13, 10,  0,  0, 10,  4,  5,  8],
#        device='cuda:0')
# predicted = tensor([ 8,  5,  3,  2,  9, 11,  6,  1,  1, 13, 11, 11,  0,  3,  5,  8],
#        device='cuda:0'),
#  total  = 10208, correct = 1863
# tensor([ 3,  0,  8,  6, 10,  4,  8,  0,  0,  1,  2,  7,  6, 10, 10, 11],
#        device='cuda:0')
# predicted = tensor([ 8,  3,  8,  8, 10, 13,  8, 11,  0,  1,  2,  5,  8, 10, 12,  7],
#        device='cuda:0'),
#  total  = 10224, correct = 1870
# tensor([ 3, 13,  3,  6, 12, 11, 10, 12,  4,  3, 12,  0,  0,  6, 10,  8],
#        device='cuda:0')
# predicted = tensor([ 9,  5,  4,  8, 11,  7, 10,  6,  5,  5,  6,  3,  0,  1,  9,  4],
#        device='cuda:0'),
#  total  = 10240, correct = 1872
# tensor([ 6,  0,  9,  3,  1,  9,  0, 11,  1,  0,  2,  1, 13,  8,  9,  1],
#        device='cuda:0')
# predicted = tensor([ 8, 11,  1,  4,  9,  8,  5,  8,  3,  3, 12, 12, 13,  8,  1,  1],
#        device='cuda:0'),
#  total  = 10256, correct = 1875
# tensor([ 6,  9,  0,  4,  3, 11,  4,  4,  0,  1,  1,  9,  3, 13,  2,  2],
#        device='cuda:0')
# predicted = tensor([ 3,  2,  3,  3,  9,  0, 13,  9, 11,  0,  4,  0, 10, 13,  2,  4],
#        device='cuda:0'),
#  total  = 10272, correct = 1877
# tensor([ 3,  0, 11, 10,  6,  5,  9,  2,  3, 12, 12,  6,  5,  3,  1,  4],
#        device='cuda:0')
# predicted = tensor([ 5,  5, 11,  0,  1,  9,  1,  2,  5, 11,  8,  6, 13,  5,  1,  1],
#        device='cuda:0'),
#  total  = 10288, correct = 1881
# tensor([ 8,  0,  5,  1,  4,  6,  1,  2,  2,  9,  9, 11,  1,  4, 10,  0],
#        device='cuda:0')
# predicted = tensor([ 9, 11,  5,  9,  1,  6,  0,  2,  1,  9,  2,  0,  9,  3,  0, 11],
#        device='cuda:0'),
#  total  = 10304, correct = 1885
# tensor([12,  6,  5, 13, 12,  2,  1,  1,  6,  8,  8, 10,  9, 12,  0,  9],
#        device='cuda:0')
# predicted = tensor([ 9, 10,  5, 13,  8,  2,  5, 13,  9,  0,  8,  2, 13, 11,  5,  2],
#        device='cuda:0'),
#  total  = 10320, correct = 1889
# tensor([ 3, 12,  8, 10, 11,  6,  2,  9, 12,  6, 12,  7, 10,  6,  0,  0],
#        device='cuda:0')
# predicted = tensor([ 4, 11, 11, 10, 11,  8, 12,  1,  8, 10,  2, 12,  2,  3,  3,  5],
#        device='cuda:0'),
#  total  = 10336, correct = 1891
# tensor([ 6,  5, 13,  1, 11,  9, 10, 11,  8, 12,  2, 11, 10,  9,  0, 10],
#        device='cuda:0')
# predicted = tensor([ 1,  2, 13, 12, 11,  2,  2,  8, 10,  6,  2,  8,  2,  1, 11, 10],
#        device='cuda:0'),
#  total  = 10352, correct = 1895
# tensor([ 5, 13,  0, 11, 13,  6,  1,  4,  2, 10,  5, 10, 12,  5,  6,  0],
#        device='cuda:0')
# predicted = tensor([ 5, 13,  0,  0, 13,  8,  1,  5,  1,  9,  6, 10,  5, 10,  6,  3],
#        device='cuda:0'),
#  total  = 10368, correct = 1902
# tensor([ 0,  8,  6,  1, 13, 13, 10,  2,  3, 12, 11,  3,  0, 10,  4,  3],
#        device='cuda:0')
# predicted = tensor([13,  6,  1, 13, 13, 13,  5, 12,  4, 10,  0,  8,  1, 12, 10,  9],
#        device='cuda:0'),
#  total  = 10384, correct = 1904
# tensor([10,  9,  4,  6,  2, 12, 11,  2,  6, 10, 10,  9,  3,  0,  0, 13],
#        device='cuda:0')
# predicted = tensor([ 0,  9,  3,  8,  3,  8, 11,  0,  5, 13,  5,  6,  4, 11, 13, 13],
#        device='cuda:0'),
#  total  = 10400, correct = 1907
# tensor([ 0,  4,  9,  9,  0,  1, 12, 13,  0,  3,  3,  4,  4,  5,  7,  4],
#        device='cuda:0')
# predicted = tensor([ 3,  3,  6,  2,  3,  9,  5, 13,  5,  5, 10, 10, 10,  5,  8,  3],
#        device='cuda:0'),
#  total  = 10416, correct = 1909
# tensor([ 2,  3,  3,  0,  7, 13, 12, 10, 10,  0,  2,  1, 10,  1, 10,  8],
#        device='cuda:0')
# predicted = tensor([ 0,  5,  5,  1, 10,  5,  5,  2,  2, 11,  2, 13,  2,  1,  5,  9],
#        device='cuda:0'),
#  total  = 10432, correct = 1911
# tensor([ 0,  9,  5,  2,  9,  0, 10,  1,  7,  0,  7,  0,  4, 12, 10,  3],
#        device='cuda:0')
# predicted = tensor([ 3,  1, 10,  3,  6, 11,  2,  9, 10,  0,  9, 11, 10, 11,  2,  5],
#        device='cuda:0'),
#  total  = 10448, correct = 1912
# tensor([ 6, 12,  4, 11, 12, 11,  9,  3,  8,  0,  6,  8, 13,  7,  3, 12],
#        device='cuda:0')
# predicted = tensor([ 1, 11,  9, 10,  8,  0,  9,  5,  9, 13,  1,  6, 13, 10,  9,  8],
#        device='cuda:0'),
#  total  = 10464, correct = 1914
# tensor([ 6, 11,  3,  2,  2,  5, 12, 11,  1, 12,  9, 11,  2, 13,  4, 12],
#        device='cuda:0')
# predicted = tensor([ 8,  8,  0,  6,  2,  6, 11,  8, 11,  6,  1,  2,  5, 13,  3,  0],
#        device='cuda:0'),
#  total  = 10480, correct = 1916
# tensor([ 8,  8, 13,  6,  3,  8,  8,  0,  4,  6,  1,  9,  2, 11, 11,  6],
#        device='cuda:0')
# predicted = tensor([ 8,  8, 13,  8, 10,  8,  7, 13, 12,  1,  4,  2, 12,  6, 11,  6],
#        device='cuda:0'),
#  total  = 10496, correct = 1922
# tensor([12,  7, 11,  6, 11,  3,  2,  0,  0,  2,  4,  6,  7,  0,  6, 12],
#        device='cuda:0')
# predicted = tensor([ 6, 10, 10,  8,  8,  5,  2,  5, 11,  0,  5,  0,  8,  1,  1,  9],
#        device='cuda:0'),
#  total  = 10512, correct = 1923
# tensor([ 8,  7,  0,  0, 11,  2,  0,  5, 10,  0,  4,  6,  1,  2,  0,  2],
#        device='cuda:0')
# predicted = tensor([10,  8, 10, 13,  8,  3,  0, 12,  2,  3,  9, 10,  4,  2,  1,  8],
#        device='cuda:0'),
#  total  = 10528, correct = 1925
# tensor([ 5,  0,  6, 10,  3, 11, 11,  8, 11,  5, 10,  0,  2,  7,  9,  6],
#        device='cuda:0')
# predicted = tensor([ 3,  3,  1, 12,  4,  8, 10,  8,  0, 10,  2,  5,  9,  4,  1,  6],
#        device='cuda:0'),
#  total  = 10544, correct = 1927
# tensor([10, 10,  6,  9, 12, 10,  8, 10,  1,  3, 13, 13,  3,  6,  0,  8],
#        device='cuda:0')
# predicted = tensor([ 9, 12, 10,  1, 11,  2,  4,  5,  1,  3, 13,  5, 10,  3, 11,  9],
#        device='cuda:0'),
#  total  = 10560, correct = 1930
# tensor([ 6, 13,  2,  1,  8, 10,  2, 13, 11,  6, 11, 13,  5,  5,  7,  1],
#        device='cuda:0')
# predicted = tensor([ 8, 13, 12,  3,  5, 12,  6, 13, 11,  6,  0, 13,  6,  5,  8,  4],
#        device='cuda:0'),
#  total  = 10576, correct = 1936
# tensor([ 2,  3, 11,  9,  5,  2,  0,  6,  0,  5,  5, 11,  2,  9,  6, 10],
#        device='cuda:0')
# predicted = tensor([ 2,  1, 11,  1, 10, 12, 11,  6, 11,  2,  0,  8,  2,  6,  3,  5],
#        device='cuda:0'),
#  total  = 10592, correct = 1940
# tensor([10, 10,  3, 11,  5, 11], device='cuda:0')
# predicted = tensor([ 2, 10,  1, 11, 13,  0], device='cuda:0'),
#  total  = 10598, correct = 1942
# Accuracy of the model on the test dataset: 18.32%
